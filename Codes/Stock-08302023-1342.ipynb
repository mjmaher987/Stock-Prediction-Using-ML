# %% [markdown]
# <a href="https://colab.research.google.com/github/mjmaher987/Stock-Prediction-Using-ML/blob/main/Codes/Stock-08302023-1342.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stock Price Prediction

# %% [markdown]
# ## Dependencies

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.layers import Input, Dense, MultiHeadAttention, Reshape, Flatten, LSTM
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# ## Configs

# %%
Configs = {
    "training_percent" : 0.8,
    "window_size" : 5,
    "epoch_number" : 50,
    "sequence_length" : 10,
    "num_features" : 5
}

# %% [markdown]
# ## Preprocessing

# %%
class ETL:
    """
    ticker: str
    period: string
    test_size: float betwee 0 and 1
    n_input: int
    timestep: int
    Extracts data for stock with ticker `ticker` from yf api,
    splits the data into train and test sets by date,
    reshapes the data into np.array of shape [#weeks, 5, 1],
    converts our problem into supervised learning problem.
    """
    def __init__(self, ticker, test_size=0.2, period='max', n_input=5, timestep=5) -> None:
        self.ticker = ticker
        self.period = period
        self.test_size = test_size
        self.n_input = n_input
        self.df = self.extract_historic_data()
        self.timestep = timestep
        self.train, self.test = self.etl()
        self.X_train, self.y_train = self.to_supervised(self.train)
        self.X_test, self.y_test = self.to_supervised(self.test)

    def get_history_from_yf(self):
        t = yf.Ticker(self.ticker)
        return t.history(period=self.period)

    def extract_historic_data(self) -> pd.Series:
        """
        gets historical data from yf api.
        """
        t = yf.Ticker(self.ticker)
        history = t.history(period=self.period)
        return history.Close

    def split_data(self) -> tuple:
        """
        Splits our pd.Series into train and test series with
        test series representing test_size * 100 % of data.
        """
        data = self.extract_historic_data()
        if len(data) != 0:
            train_idx = round(len(data) * (1-self.test_size))
            train = data[:train_idx]
            test = data[train_idx:]
            train = np.array(train)
            test = np.array(test)
            return train[:, np.newaxis], test[:, np.newaxis]
        else:
            raise Exception('Data set is empty, cannot split.')

    def window_and_reshape(self, data) -> np.array:
        """
        Reformats data into shape our model needs,
        namely, [# samples, timestep, # feautures]
        samples
        """
        NUM_FEATURES = 1
        samples = int(data.shape[0] / self.timestep)
        result = np.array(np.array_split(data, samples))
        return result.reshape((samples, self.timestep, NUM_FEATURES))

    def transform(self, train, test) -> np.array:
        train_remainder = train.shape[0] % self.timestep
        test_remainder = test.shape[0] % self.timestep
        if train_remainder != 0 and test_remainder != 0:
            train = train[train_remainder:]
            test = test[test_remainder:]
        elif train_remainder != 0:
            train = train[train_remainder:]
        elif test_remainder != 0:
            test = test[test_remainder:]
        return self.window_and_reshape(train), self.window_and_reshape(test)

    def etl(self) -> tuple[np.array, np.array]:
        """
        Runs complete ETL
        """
        train, test = self.split_data()
        return self.transform(train, test)

    def to_supervised(self, train, n_out=5) -> tuple:
        """
        Converts our time series prediction problem to a
        supervised learning problem.
        """
        # flatted the data
        data = train.reshape((train.shape[0]*train.shape[1], train.shape[2]))
        X, y = [], []
        in_start = 0
        # step over the entire history one time step at a time
        for _ in range(len(data)):
            # define the end of the input sequence
            in_end = in_start + self.n_input
            out_end = in_end + n_out
            # ensure we have enough data for this instance
            if out_end <= len(data):
                x_input = data[in_start:in_end, 0]
                x_input = x_input.reshape((len(x_input), 1))
                X.append(x_input)
                y.append(data[in_end:out_end, 0])
                # move along one time step
                in_start += 1
        return np.array(X), np.array(y)

# %%
etl_data = ETL('EURUSD=X')
history = etl_data.get_history_from_yf()

data = pd.DataFrame(
    {
        'open': pd.Series([x for x in history.Open]),
        'high': pd.Series([x for x in history.High]),
        'low': pd.Series([x for x in history.Low]),
        'close': pd.Series([x for x in history.Close]),
        'volume': pd.Series([x for x in history.Volume]),
    }
)

# Preprocessing
scaler = MinMaxScaler()
data['close'] = scaler.fit_transform(data['close'].values.reshape(-1, 1))

# Splitting into training and testing sets
train_size = int(Configs['training_percent'] * len(data))
train_data, test_data = data[:train_size], data[train_size:]

# %%
# Define the sequence length
sequence_length = Configs['sequence_length']
def create_sequences(data, sequence_length):
    sequences = []
    targets = []
    for i in range(len(data) - sequence_length):
        sequences.append(data[i:i+sequence_length])
        targets.append(data.iloc[i+sequence_length])
    return np.array(sequences), np.array(targets)
train_sequences, train_targets = create_sequences(train_data, sequence_length)
test_sequences, test_targets = create_sequences(test_data, sequence_length)

# %% [markdown]
# ## Experiments

# %% [markdown]
# ### Ichimoku

# %%
def calculate_ichimoku_cloud(df):
    # Tenkan-sen (Conversion Line) - Average of the highest high and lowest low over a certain period
    df['tenkan_sen'] = (df['high'].rolling(window=9).max() + df['low'].rolling(window=9).min()) / 2

    # Kijun-sen (Base Line) - Average of the highest high and lowest low over a longer period
    df['kijun_sen'] = (df['high'].rolling(window=26).max() + df['low'].rolling(window=26).min()) / 2

    # Senkou Span A (Leading Span A) - Average of the Tenkan-sen and Kijun-sen, shifted forward
    df['senkou_span_a'] = ((df['tenkan_sen'] + df['kijun_sen']) / 2).shift(26)

    # Senkou Span B (Leading Span B) - Average of the highest high and lowest low over an even longer period, shifted forward
    df['senkou_span_b'] = ((df['high'].rolling(window=52).max() + df['low'].rolling(window=52).min()) / 2).shift(26)

    # Chikou Span (Lagging Span) - Close price shifted backward
    df['chikou_span'] = df['close'].shift(-26)

    return df[['tenkan_sen', 'kijun_sen', 'senkou_span_a', 'senkou_span_b', 'chikou_span']]

# Calculate Ichimoku Cloud components
data_with_cloud = calculate_ichimoku_cloud(data)

def ichimoku_trading_strategy(df):
    signals = []
    for i in range(len(df)):
        if data['close'][i] > df['senkou_span_a'][i] and data['close'][i] > df['senkou_span_b'][i]:
            signals.append('Buy')
        elif data['close'][i] < df['senkou_span_a'][i] and data['close'][i] < df['senkou_span_b'][i]:
            signals.append('Sell')
        else:
            signals.append('Hold')
    return signals

# Generate trading signals using the Ichimoku-based strategy
trading_signals = ichimoku_trading_strategy(data_with_cloud)

# Print the trading signals
for i, signal in enumerate(trading_signals):
    print(f"Day {i + 1}: {signal}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Day 125: Sell
# Day 126: Sell
# ...
# ...
# ...
# Day 5121: Sell
# Day 5122: Sell
# Day 5123: Sell
# Day 5124: Sell

# %%
data_with_cloud
# Out:
#       tenkan_sen  kijun_sen  senkou_span_a  senkou_span_b  chikou_span
# 0            NaN        NaN            NaN            NaN     0.488883
# 1            NaN        NaN            NaN            NaN     0.476354
# 2            NaN        NaN            NaN            NaN     0.497324
# 3            NaN        NaN            NaN            NaN     0.510457
# 4            NaN        NaN            NaN            NaN     0.492002
# ...          ...        ...            ...            ...          ...
# 5119    1.088167   1.101632       1.104896        1.09637          NaN
# 5120    1.085818   1.095935       1.107506        1.09637          NaN
# 5121    1.085070   1.095935       1.109112        1.09637          NaN
# 5122    1.084935   1.095935       1.109967        1.09637          NaN
# 5123    1.084935   1.095935       1.110198        1.09637          NaN
#
# [5124 rows x 5 columns]

# %% [markdown]
# ###NBEATS

# %%
class NBitsModel(tf.keras.Model):
    def __init__(self):
        super(NBitsModel, self).__init__()
        self.flatten = tf.keras.layers.Flatten(input_shape=(Configs['sequence_length'], 5))
        self.dense = tf.keras.layers.Dense(5)

    def call(self, inputs, training):
        x = self.flatten(inputs)
        x = self.dense(x)
        return x

model = NBitsModel()
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(train_sequences, train_targets, epochs=Configs['epoch_number'], batch_size=32, validation_split=0.2)

# Make predictions
predictions_nbits = model.predict(test_sequences)
mse = mean_squared_error(test_targets, predictions_nbits)
mae = mean_absolute_error(test_targets, predictions_nbits)
rmse = mean_squared_error(test_targets, predictions_nbits, squared=False)
print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Epoch 1/50
# 103/103 [==============================] - 2s 8ms/step - loss: 0.1709 - val_loss: 0.0130
# Epoch 2/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0117
# Epoch 3/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0079
# Epoch 4/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0056
# Epoch 5/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0029 - val_loss: 0.0043
# Epoch 6/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 7/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 8/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 9/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 10/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 11/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 9.7950e-04
# Epoch 12/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 7.3171e-04
# Epoch 13/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 8.5222e-04
# Epoch 14/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 4.3372e-04
# Epoch 15/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 3.4655e-04
# Epoch 16/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 3.7836e-04
# Epoch 17/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 2.0567e-04
# Epoch 18/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 1.9679e-04
# Epoch 19/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 2.0322e-04
# Epoch 20/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 4.0141e-04
# Epoch 21/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 2.7929e-04
# Epoch 22/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 1.7841e-04
# Epoch 23/50
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 1.7201e-04
# Epoch 24/50
# 103/103 [==============================] - 0s 2ms/step - loss: 9.9234e-04 - val_loss: 1.8006e-04
# Epoch 25/50
# 103/103 [==============================] - 0s 2ms/step - loss: 9.8791e-04 - val_loss: 1.8038e-04
# Epoch 26/50
# 103/103 [==============================] - 0s 2ms/step - loss: 9.8167e-04 - val_loss: 1.7706e-04
# Epoch 27/50
# 103/103 [==============================] - 0s 3ms/step - loss: 9.7967e-04 - val_loss: 1.7198e-04
# Epoch 28/50
# 103/103 [==============================] - 0s 2ms/step - loss: 9.6170e-04 - val_loss: 1.5968e-04
# Epoch 29/50
# 103/103 [==============================] - 0s 2ms/step - loss: 9.5843e-04 - val_loss: 1.5862e-04
# Epoch 30/50
# 103/103 [==============================] - 0s 2ms/step - loss: 9.4412e-04 - val_loss: 1.9353e-04
# Epoch 31/50
# 103/103 [==============================] - 0s 2ms/step - loss: 9.4025e-04 - val_loss: 1.5741e-04
# Epoch 32/50
# 103/103 [==============================] - 0s 2ms/step - loss: 9.2029e-04 - val_loss: 1.7336e-04
# Epoch 33/50
# 103/103 [==============================] - 0s 3ms/step - loss: 9.2535e-04 - val_loss: 1.6744e-04
# Epoch 34/50
# 103/103 [==============================] - 0s 4ms/step - loss: 9.0840e-04 - val_loss: 1.5603e-04
# Epoch 35/50
# 103/103 [==============================] - 0s 4ms/step - loss: 9.0753e-04 - val_loss: 1.5018e-04
# Epoch 36/50
# 103/103 [==============================] - 1s 5ms/step - loss: 8.8496e-04 - val_loss: 1.6022e-04
# Epoch 37/50
# 103/103 [==============================] - 1s 6ms/step - loss: 8.7784e-04 - val_loss: 1.5928e-04
# Epoch 38/50
# 103/103 [==============================] - 1s 6ms/step - loss: 8.7588e-04 - val_loss: 1.5532e-04
# Epoch 39/50
# 103/103 [==============================] - 1s 7ms/step - loss: 8.4942e-04 - val_loss: 4.2183e-04
# Epoch 40/50
# 103/103 [==============================] - 1s 7ms/step - loss: 8.8044e-04 - val_loss: 2.3874e-04
# Epoch 41/50
# 103/103 [==============================] - 0s 4ms/step - loss: 8.5528e-04 - val_loss: 1.3417e-04
# Epoch 42/50
# 103/103 [==============================] - 0s 4ms/step - loss: 8.4038e-04 - val_loss: 1.2190e-04
# Epoch 43/50
# 103/103 [==============================] - 0s 3ms/step - loss: 8.0960e-04 - val_loss: 1.2953e-04
# Epoch 44/50
# 103/103 [==============================] - 0s 3ms/step - loss: 8.1097e-04 - val_loss: 1.6755e-04
# Epoch 45/50
# 103/103 [==============================] - 0s 4ms/step - loss: 8.1391e-04 - val_loss: 1.1646e-04
# Epoch 46/50
# 103/103 [==============================] - 0s 4ms/step - loss: 8.0943e-04 - val_loss: 1.8980e-04
# Epoch 47/50
# 103/103 [==============================] - 0s 4ms/step - loss: 7.9710e-04 - val_loss: 1.1585e-04
# Epoch 48/50
# 103/103 [==============================] - 0s 4ms/step - loss: 7.8206e-04 - val_loss: 1.1276e-04
# Epoch 49/50
# 103/103 [==============================] - 0s 3ms/step - loss: 7.6123e-04 - val_loss: 1.2209e-04
# Epoch 50/50
# 103/103 [==============================] - 0s 2ms/step - loss: 7.5763e-04 - val_loss: 1.0070e-04
# 32/32 [==============================] - 0s 1ms/step
# Mean Squared Error: 0.00012352611798264153
# Mean Absolute Error: 0.008094370164550425
# Root Mean Squared Error: 0.010561611964398778

# %% [markdown]
# ###NHEATS

# %%
def build_nhits(input_shape, output_shape):
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=input_shape),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(output_shape)
    ])
    return model

nhits_model = build_nhits((Configs['sequence_length'], 5), 5)
nhits_model.compile(optimizer='adam', loss='mean_squared_error')
nhits_model.fit(train_sequences, train_targets, epochs=Configs['epoch_number'], batch_size=32, validation_split=0.2)


nhits_predictions = nhits_model.predict(test_sequences)
mse = mean_squared_error(test_targets, nhits_predictions)
mae = mean_absolute_error(test_targets, nhits_predictions)
rmse = mean_squared_error(test_targets, nhits_predictions, squared=False)
print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Epoch 1/50
# 103/103 [==============================] - 1s 4ms/step - loss: 0.0331 - val_loss: 0.0016
# Epoch 2/50
# 103/103 [==============================] - 0s 3ms/step - loss: 6.8517e-04 - val_loss: 1.3864e-04
# Epoch 3/50
# 103/103 [==============================] - 0s 3ms/step - loss: 5.2823e-04 - val_loss: 2.2425e-04
# Epoch 4/50
# 103/103 [==============================] - 0s 2ms/step - loss: 5.1704e-04 - val_loss: 1.1985e-04
# Epoch 5/50
# 103/103 [==============================] - 0s 2ms/step - loss: 5.0429e-04 - val_loss: 1.0061e-04
# Epoch 6/50
# 103/103 [==============================] - 0s 2ms/step - loss: 4.9134e-04 - val_loss: 1.0621e-04
# Epoch 7/50
# 103/103 [==============================] - 0s 5ms/step - loss: 5.1426e-04 - val_loss: 1.1195e-04
# Epoch 8/50
# 103/103 [==============================] - 0s 3ms/step - loss: 5.0304e-04 - val_loss: 9.8528e-05
# Epoch 9/50
# 103/103 [==============================] - 0s 4ms/step - loss: 5.0544e-04 - val_loss: 9.4078e-05
# Epoch 10/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.8137e-04 - val_loss: 1.5045e-04
# Epoch 11/50
# 103/103 [==============================] - 1s 7ms/step - loss: 4.9400e-04 - val_loss: 1.1234e-04
# Epoch 12/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.7969e-04 - val_loss: 2.3225e-04
# Epoch 13/50
# 103/103 [==============================] - 0s 3ms/step - loss: 4.7002e-04 - val_loss: 1.0965e-04
# Epoch 14/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.4333e-04 - val_loss: 1.4087e-04
# Epoch 15/50
# 103/103 [==============================] - 0s 5ms/step - loss: 4.6772e-04 - val_loss: 7.4411e-05
# Epoch 16/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.8128e-04 - val_loss: 8.7476e-05
# Epoch 17/50
# 103/103 [==============================] - 0s 5ms/step - loss: 4.6338e-04 - val_loss: 1.3279e-04
# Epoch 18/50
# 103/103 [==============================] - 1s 5ms/step - loss: 4.3501e-04 - val_loss: 6.2107e-05
# Epoch 19/50
# 103/103 [==============================] - 1s 8ms/step - loss: 4.5770e-04 - val_loss: 6.8113e-05
# Epoch 20/50
# 103/103 [==============================] - 1s 7ms/step - loss: 4.3835e-04 - val_loss: 7.5950e-05
# Epoch 21/50
# 103/103 [==============================] - 1s 7ms/step - loss: 4.3614e-04 - val_loss: 6.7811e-05
# Epoch 22/50
# 103/103 [==============================] - 1s 6ms/step - loss: 4.2674e-04 - val_loss: 6.0031e-04
# Epoch 23/50
# 103/103 [==============================] - 1s 7ms/step - loss: 4.9034e-04 - val_loss: 1.6550e-04
# Epoch 24/50
# 103/103 [==============================] - 1s 5ms/step - loss: 4.4197e-04 - val_loss: 6.7043e-05
# Epoch 25/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.0489e-04 - val_loss: 7.8708e-05
# Epoch 26/50
# 103/103 [==============================] - 1s 5ms/step - loss: 4.3660e-04 - val_loss: 1.9333e-04
# Epoch 27/50
# 103/103 [==============================] - 1s 6ms/step - loss: 4.6157e-04 - val_loss: 1.1522e-04
# Epoch 28/50
# 103/103 [==============================] - 1s 6ms/step - loss: 4.2057e-04 - val_loss: 3.9876e-04
# Epoch 29/50
# 103/103 [==============================] - 0s 5ms/step - loss: 4.0499e-04 - val_loss: 2.1281e-04
# Epoch 30/50
# 103/103 [==============================] - 0s 3ms/step - loss: 4.1938e-04 - val_loss: 4.9105e-05
# Epoch 31/50
# 103/103 [==============================] - 0s 3ms/step - loss: 4.0858e-04 - val_loss: 7.0812e-05
# Epoch 32/50
# 103/103 [==============================] - 0s 2ms/step - loss: 4.0915e-04 - val_loss: 6.9121e-05
# Epoch 33/50
# 103/103 [==============================] - 0s 3ms/step - loss: 3.7390e-04 - val_loss: 4.9136e-04
# Epoch 34/50
# 103/103 [==============================] - 0s 2ms/step - loss: 4.6667e-04 - val_loss: 1.9713e-04
# Epoch 35/50
# 103/103 [==============================] - 0s 2ms/step - loss: 4.0827e-04 - val_loss: 5.4434e-05
# Epoch 36/50
# 103/103 [==============================] - 0s 2ms/step - loss: 4.0334e-04 - val_loss: 6.2258e-05
# Epoch 37/50
# 103/103 [==============================] - 0s 3ms/step - loss: 4.0580e-04 - val_loss: 5.5885e-05
# Epoch 38/50
# 103/103 [==============================] - 0s 2ms/step - loss: 3.6408e-04 - val_loss: 5.3152e-05
# Epoch 39/50
# 103/103 [==============================] - 0s 3ms/step - loss: 4.2118e-04 - val_loss: 7.1260e-05
# Epoch 40/50
# 103/103 [==============================] - 0s 3ms/step - loss: 3.8234e-04 - val_loss: 1.2013e-04
# Epoch 41/50
# 103/103 [==============================] - 0s 2ms/step - loss: 3.9391e-04 - val_loss: 8.5279e-05
# Epoch 42/50
# 103/103 [==============================] - 0s 2ms/step - loss: 3.6923e-04 - val_loss: 5.6190e-05
# Epoch 43/50
# 103/103 [==============================] - 0s 3ms/step - loss: 3.6663e-04 - val_loss: 1.1109e-04
# Epoch 44/50
# 103/103 [==============================] - 0s 2ms/step - loss: 4.1972e-04 - val_loss: 1.1980e-04
# Epoch 45/50
# 103/103 [==============================] - 0s 2ms/step - loss: 4.1676e-04 - val_loss: 1.2919e-04
# Epoch 46/50
# 103/103 [==============================] - 0s 3ms/step - loss: 3.8321e-04 - val_loss: 5.0043e-05
# Epoch 47/50
# 103/103 [==============================] - 0s 3ms/step - loss: 4.0247e-04 - val_loss: 5.2317e-05
# Epoch 48/50
# 103/103 [==============================] - 0s 2ms/step - loss: 3.8119e-04 - val_loss: 7.2424e-05
# Epoch 49/50
# 103/103 [==============================] - 0s 3ms/step - loss: 3.7845e-04 - val_loss: 1.2178e-04
# Epoch 50/50
# 103/103 [==============================] - 0s 2ms/step - loss: 3.9258e-04 - val_loss: 6.7473e-05
# 32/32 [==============================] - 0s 2ms/step
# Mean Squared Error: 7.88085919048775e-05
# Mean Absolute Error: 0.006319218506092727
# Root Mean Squared Error: 0.008113229858371807

# %% [markdown]
# ###RNN

# %%
model_rnn = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(64, input_shape=(Configs['sequence_length'], 5), return_sequences=False),
    tf.keras.layers.Dense(5)
])

model_rnn.compile(optimizer='adam', loss='mean_squared_error')
model_rnn.fit(train_sequences, train_targets, epochs=Configs['epoch_number'], batch_size=32, validation_split=0.2)


# Make predictions
predictions_rnn = model_rnn.predict(test_sequences)
mse = mean_squared_error(test_targets, predictions_rnn)
mae = mean_absolute_error(test_targets, predictions_rnn)
rmse = mean_squared_error(test_targets, predictions_rnn, squared=False)
print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Epoch 1/50
# 103/103 [==============================] - 2s 6ms/step - loss: 0.0380 - val_loss: 0.0016
# Epoch 2/50
# 103/103 [==============================] - 0s 4ms/step - loss: 6.7384e-04 - val_loss: 2.2493e-04
# Epoch 3/50
# 103/103 [==============================] - 0s 4ms/step - loss: 5.1583e-04 - val_loss: 1.0562e-04
# Epoch 4/50
# 103/103 [==============================] - 0s 5ms/step - loss: 4.9577e-04 - val_loss: 1.1650e-04
# Epoch 5/50
# 103/103 [==============================] - 0s 5ms/step - loss: 4.9508e-04 - val_loss: 1.5445e-04
# Epoch 6/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.6277e-04 - val_loss: 8.7632e-05
# Epoch 7/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.6514e-04 - val_loss: 6.9754e-05
# Epoch 8/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.3564e-04 - val_loss: 9.7815e-05
# Epoch 9/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.1846e-04 - val_loss: 1.5083e-04
# Epoch 10/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.4584e-04 - val_loss: 8.2278e-05
# Epoch 11/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.5484e-04 - val_loss: 6.5909e-05
# Epoch 12/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.9784e-04 - val_loss: 1.1079e-04
# Epoch 13/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.0792e-04 - val_loss: 1.9934e-04
# Epoch 14/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.0348e-04 - val_loss: 8.7691e-05
# Epoch 15/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.0959e-04 - val_loss: 1.0504e-04
# Epoch 16/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.9699e-04 - val_loss: 1.3935e-04
# Epoch 17/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.1960e-04 - val_loss: 5.4731e-05
# Epoch 18/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.2097e-04 - val_loss: 2.5353e-04
# Epoch 19/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.0494e-04 - val_loss: 1.0786e-04
# Epoch 20/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.9401e-04 - val_loss: 6.7763e-05
# Epoch 21/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.7542e-04 - val_loss: 2.7735e-04
# Epoch 22/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.8806e-04 - val_loss: 5.0970e-05
# Epoch 23/50
# 103/103 [==============================] - 1s 5ms/step - loss: 4.0854e-04 - val_loss: 7.7802e-04
# Epoch 24/50
# 103/103 [==============================] - 1s 6ms/step - loss: 3.9304e-04 - val_loss: 2.4077e-04
# Epoch 25/50
# 103/103 [==============================] - 1s 6ms/step - loss: 3.7388e-04 - val_loss: 3.1323e-04
# Epoch 26/50
# 103/103 [==============================] - 1s 6ms/step - loss: 3.7121e-04 - val_loss: 2.1360e-04
# Epoch 27/50
# 103/103 [==============================] - 1s 7ms/step - loss: 3.7525e-04 - val_loss: 1.0233e-04
# Epoch 28/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.9206e-04 - val_loss: 1.1722e-04
# Epoch 29/50
# 103/103 [==============================] - 0s 5ms/step - loss: 3.5188e-04 - val_loss: 1.2790e-04
# Epoch 30/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.9555e-04 - val_loss: 3.0804e-04
# Epoch 31/50
# 103/103 [==============================] - 0s 4ms/step - loss: 4.1195e-04 - val_loss: 6.7120e-05
# Epoch 32/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.5979e-04 - val_loss: 1.4793e-04
# Epoch 33/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.7820e-04 - val_loss: 1.1128e-04
# Epoch 34/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.5692e-04 - val_loss: 1.0230e-04
# Epoch 35/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.7293e-04 - val_loss: 8.3096e-05
# Epoch 36/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.7523e-04 - val_loss: 6.9028e-05
# Epoch 37/50
# 103/103 [==============================] - 1s 5ms/step - loss: 3.6525e-04 - val_loss: 5.1561e-04
# Epoch 38/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.6539e-04 - val_loss: 1.5806e-04
# Epoch 39/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.5191e-04 - val_loss: 1.3340e-04
# Epoch 40/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.7971e-04 - val_loss: 7.4560e-05
# Epoch 41/50
# 103/103 [==============================] - 1s 5ms/step - loss: 3.7582e-04 - val_loss: 4.0035e-05
# Epoch 42/50
# 103/103 [==============================] - 1s 5ms/step - loss: 3.5040e-04 - val_loss: 5.7996e-05
# Epoch 43/50
# 103/103 [==============================] - 1s 6ms/step - loss: 3.6237e-04 - val_loss: 2.6982e-04
# Epoch 44/50
# 103/103 [==============================] - 1s 6ms/step - loss: 3.8863e-04 - val_loss: 4.9674e-05
# Epoch 45/50
# 103/103 [==============================] - 1s 6ms/step - loss: 3.4200e-04 - val_loss: 1.1072e-04
# Epoch 46/50
# 103/103 [==============================] - 1s 6ms/step - loss: 3.5809e-04 - val_loss: 2.9224e-04
# Epoch 47/50
# 103/103 [==============================] - 0s 4ms/step - loss: 3.6045e-04 - val_loss: 2.3800e-04
# Epoch 48/50
# 103/103 [==============================] - 1s 6ms/step - loss: 3.5041e-04 - val_loss: 4.5636e-05
# Epoch 49/50
# 103/103 [==============================] - 1s 13ms/step - loss: 3.5971e-04 - val_loss: 4.4803e-05
# Epoch 50/50
# 103/103 [==============================] - 1s 10ms/step - loss: 3.4820e-04 - val_loss: 1.3304e-04
# 32/32 [==============================] - 0s 2ms/step
# Mean Squared Error: 0.00014181498182983101
# Mean Absolute Error: 0.009261964201881323
# Root Mean Squared Error: 0.010488586044253845

# %% [markdown]
# ###LSTM

# %%
lstm_model = tf.keras.Sequential([
    tf.keras.layers.LSTM(64, input_shape=(sequence_length, 5), return_sequences=False),
    tf.keras.layers.Dense(5)
])

lstm_model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

lstm_model.fit(train_sequences, train_targets, epochs=Configs['epoch_number'], batch_size=32, verbose=1)


lstm_predictions = lstm_model.predict(test_sequences)
mse = mean_squared_error(test_targets, lstm_predictions)
mae = mean_absolute_error(test_targets, lstm_predictions)
rmse = mean_squared_error(test_targets, lstm_predictions, squared=False)
print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Epoch 1/50
# 128/128 [==============================] - 3s 8ms/step - loss: 0.0605
# Epoch 2/50
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0010
# Epoch 3/50
# 128/128 [==============================] - 1s 11ms/step - loss: 4.0696e-04
# Epoch 4/50
# 128/128 [==============================] - 1s 9ms/step - loss: 3.9569e-04
# Epoch 5/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.9987e-04
# Epoch 6/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.7819e-04
# Epoch 7/50
# 128/128 [==============================] - 1s 7ms/step - loss: 4.0342e-04
# Epoch 8/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.8793e-04
# Epoch 9/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.9762e-04
# Epoch 10/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.7041e-04
# Epoch 11/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.7354e-04
# Epoch 12/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.7395e-04
# Epoch 13/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.5816e-04
# Epoch 14/50
# 128/128 [==============================] - 2s 12ms/step - loss: 3.5520e-04
# Epoch 15/50
# 128/128 [==============================] - 1s 10ms/step - loss: 3.5858e-04
# Epoch 16/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.4957e-04
# Epoch 17/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.5846e-04
# Epoch 18/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.4316e-04
# Epoch 19/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.4317e-04
# Epoch 20/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.2414e-04
# Epoch 21/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.0790e-04
# Epoch 22/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.4399e-04
# Epoch 23/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.5011e-04
# Epoch 24/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.1772e-04
# Epoch 25/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.2812e-04
# Epoch 26/50
# 128/128 [==============================] - 1s 8ms/step - loss: 3.3434e-04
# Epoch 27/50
# 128/128 [==============================] - 1s 11ms/step - loss: 3.3502e-04
# Epoch 28/50
# 128/128 [==============================] - 1s 10ms/step - loss: 3.0715e-04
# Epoch 29/50
# 128/128 [==============================] - 1s 6ms/step - loss: 3.2974e-04
# Epoch 30/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.3695e-04
# Epoch 31/50
# 128/128 [==============================] - 1s 7ms/step - loss: 2.9643e-04
# Epoch 32/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.4721e-04
# Epoch 33/50
# 128/128 [==============================] - 1s 6ms/step - loss: 3.0311e-04
# Epoch 34/50
# 128/128 [==============================] - 1s 7ms/step - loss: 2.9685e-04
# Epoch 35/50
# 128/128 [==============================] - 1s 7ms/step - loss: 2.8769e-04
# Epoch 36/50
# 128/128 [==============================] - 2s 13ms/step - loss: 3.1345e-04
# Epoch 37/50
# 128/128 [==============================] - 1s 8ms/step - loss: 3.0294e-04
# Epoch 38/50
# 128/128 [==============================] - 1s 7ms/step - loss: 2.7172e-04
# Epoch 39/50
# 128/128 [==============================] - 1s 10ms/step - loss: 3.0641e-04
# Epoch 40/50
# 128/128 [==============================] - 1s 11ms/step - loss: 3.0361e-04
# Epoch 41/50
# 128/128 [==============================] - 1s 8ms/step - loss: 2.8975e-04
# Epoch 42/50
# 128/128 [==============================] - 1s 7ms/step - loss: 3.0894e-04
# Epoch 43/50
# 128/128 [==============================] - 1s 7ms/step - loss: 2.9798e-04
# Epoch 44/50
# 128/128 [==============================] - 1s 7ms/step - loss: 2.9415e-04
# Epoch 45/50
# 128/128 [==============================] - 1s 7ms/step - loss: 2.7590e-04
# Epoch 46/50
# 128/128 [==============================] - 1s 7ms/step - loss: 2.6348e-04
# Epoch 47/50
# 128/128 [==============================] - 1s 7ms/step - loss: 2.9294e-04
# Epoch 48/50
# 128/128 [==============================] - 1s 7ms/step - loss: 2.8347e-04
# Epoch 49/50
# 128/128 [==============================] - 1s 10ms/step - loss: 2.7588e-04
# Epoch 50/50
# 128/128 [==============================] - 1s 8ms/step - loss: 2.9081e-04
# 32/32 [==============================] - 1s 3ms/step
# Mean Squared Error: 6.338485900182476e-05
# Mean Absolute Error: 0.005592659982510416
# Root Mean Squared Error: 0.007030808680724743

# %% [markdown]
# ###Transformers

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0, epsilon=1e-6, attention_axes=None, kernel_size=1):
  """
  Creates a single transformer block.
  """
  x = layers.LayerNormalization(epsilon=epsilon)(inputs)
  x = layers.MultiHeadAttention(
      key_dim=head_size, num_heads=num_heads, dropout=dropout,
      attention_axes=attention_axes
      )(x, x)
  x = layers.Dropout(dropout)(x)
  res = x + inputs

    # Feed Forward Part
  x = layers.LayerNormalization(epsilon=epsilon)(res)
  x = layers.Conv1D(filters=ff_dim, kernel_size=kernel_size, activation="relu")(x)
  x = layers.Dropout(dropout)(x)
  x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=kernel_size)(x)
  return x + res

def build_transfromer(head_size, num_heads, ff_dim, num_trans_blocks, mlp_units, dropout=0, mlp_dropout=0, attention_axes=None, epsilon=1e-6, kernel_size=1):
  """
  Creates final model by building many transformer blocks.
  """
  n_timesteps, n_features, n_outputs = 5, 1, 5
  inputs = tf.keras.Input(shape=(n_timesteps, n_features))
  x = inputs
  for _ in range(num_trans_blocks):
    x = transformer_encoder(x, head_size=head_size, num_heads=num_heads, ff_dim=ff_dim, dropout=dropout, attention_axes=attention_axes, kernel_size=kernel_size, epsilon=epsilon)

  x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
  for dim in mlp_units:
    x = layers.Dense(dim, activation="relu")(x)
    x = layers.Dropout(mlp_dropout)(x)

  outputs = layers.Dense(n_outputs)(x)
  return tf.keras.Model(inputs, outputs)


transformer_model = build_transfromer(head_size=128, num_heads=4, ff_dim=2, num_trans_blocks=4, mlp_units=[256], mlp_dropout=0.10, dropout=0.10, attention_axes=1)

def fit_transformer(transformer: tf.keras.Model):
  """
  Compiles and fits our transformer.
  """
  transformer.compile(
    loss="mse",
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    metrics=["mae", 'mape'])

  callbacks = [tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)]
  hist = transformer.fit(etl_data.X_train, etl_data.y_train, batch_size=32, epochs=Configs['epoch_number'], verbose=1, callbacks=callbacks)
  return hist


hist = fit_transformer(transformer_model)
# Out:
# Epoch 1/50
# 128/128 [==============================] - 13s 30ms/step - loss: 0.1644 - mae: 0.2402 - mape: 18.9900
# Epoch 2/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0120 - mae: 0.0863 - mape: 6.7960
# Epoch 3/50
# 128/128 [==============================] - 3s 25ms/step - loss: 0.0091 - mae: 0.0750 - mape: 5.9081
# Epoch 4/50
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0077 - mae: 0.0695 - mape: 5.4660
# Epoch 5/50
# 128/128 [==============================] - 3s 25ms/step - loss: 0.0068 - mae: 0.0648 - mape: 5.1042
# Epoch 6/50
# 128/128 [==============================] - 4s 34ms/step - loss: 0.0061 - mae: 0.0617 - mape: 4.8552
# Epoch 7/50
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0057 - mae: 0.0599 - mape: 4.7162
# Epoch 8/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0052 - mae: 0.0570 - mape: 4.4885
# Epoch 9/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0046 - mae: 0.0538 - mape: 4.2350
# Epoch 10/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0044 - mae: 0.0523 - mape: 4.1064
# Epoch 11/50
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0041 - mae: 0.0506 - mape: 3.9763
# Epoch 12/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0039 - mae: 0.0489 - mape: 3.8445
# Epoch 13/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0038 - mae: 0.0488 - mape: 3.8409
# Epoch 14/50
# 128/128 [==============================] - 5s 40ms/step - loss: 0.0037 - mae: 0.0476 - mape: 3.7435
# Epoch 15/50
# 128/128 [==============================] - 4s 28ms/step - loss: 0.0032 - mae: 0.0453 - mape: 3.5641
# Epoch 16/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0032 - mae: 0.0447 - mape: 3.5245
# Epoch 17/50
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0032 - mae: 0.0444 - mape: 3.4951
# Epoch 18/50
# 128/128 [==============================] - 4s 28ms/step - loss: 0.0031 - mae: 0.0439 - mape: 3.4580
# Epoch 19/50
# 128/128 [==============================] - 4s 28ms/step - loss: 0.0030 - mae: 0.0429 - mape: 3.3719
# Epoch 20/50
# 128/128 [==============================] - 4s 29ms/step - loss: 0.0028 - mae: 0.0420 - mape: 3.3048
# Epoch 21/50
# 128/128 [==============================] - 4s 32ms/step - loss: 0.0028 - mae: 0.0413 - mape: 3.2359
# Epoch 22/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0027 - mae: 0.0412 - mape: 3.2404
# Epoch 23/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0026 - mae: 0.0406 - mape: 3.1865
# Epoch 24/50
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0026 - mae: 0.0402 - mape: 3.1591
# Epoch 25/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0025 - mae: 0.0399 - mape: 3.1428
# Epoch 26/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0025 - mae: 0.0393 - mape: 3.0890
# Epoch 27/50
# 128/128 [==============================] - 4s 30ms/step - loss: 0.0024 - mae: 0.0386 - mape: 3.0332
# Epoch 28/50
# 128/128 [==============================] - 4s 31ms/step - loss: 0.0023 - mae: 0.0373 - mape: 2.9349
# Epoch 29/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0022 - mae: 0.0375 - mape: 2.9516
# Epoch 30/50
# 128/128 [==============================] - 4s 27ms/step - loss: 0.0021 - mae: 0.0364 - mape: 2.8533
# Epoch 31/50
# 128/128 [==============================] - 5s 37ms/step - loss: 0.0021 - mae: 0.0362 - mape: 2.8433
# Epoch 32/50
# 128/128 [==============================] - 4s 28ms/step - loss: 0.0020 - mae: 0.0353 - mape: 2.7750
# Epoch 33/50
# 128/128 [==============================] - 4s 29ms/step - loss: 0.0020 - mae: 0.0351 - mape: 2.7502
# Epoch 34/50
# 128/128 [==============================] - 5s 36ms/step - loss: 0.0020 - mae: 0.0351 - mape: 2.7545
# Epoch 35/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0019 - mae: 0.0345 - mape: 2.7071
# Epoch 36/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0018 - mae: 0.0333 - mape: 2.6164
# Epoch 37/50
# 128/128 [==============================] - 4s 33ms/step - loss: 0.0019 - mae: 0.0347 - mape: 2.7210
# Epoch 38/50
# 128/128 [==============================] - 4s 32ms/step - loss: 0.0019 - mae: 0.0343 - mape: 2.6895
# Epoch 39/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0017 - mae: 0.0330 - mape: 2.5850
# Epoch 40/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0017 - mae: 0.0324 - mape: 2.5480
# Epoch 41/50
# 128/128 [==============================] - 4s 35ms/step - loss: 0.0016 - mae: 0.0318 - mape: 2.4952
# Epoch 42/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0016 - mae: 0.0312 - mape: 2.4498
# Epoch 43/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0016 - mae: 0.0319 - mape: 2.5007
# Epoch 44/50
# 128/128 [==============================] - 4s 31ms/step - loss: 0.0016 - mae: 0.0310 - mape: 2.4345
# Epoch 45/50
# 128/128 [==============================] - 4s 29ms/step - loss: 0.0015 - mae: 0.0306 - mape: 2.3960
# Epoch 46/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0015 - mae: 0.0303 - mape: 2.3821
# Epoch 47/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0014 - mae: 0.0295 - mape: 2.3147
# Epoch 48/50
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0015 - mae: 0.0302 - mape: 2.3716
# Epoch 49/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0014 - mae: 0.0295 - mape: 2.3157
# Epoch 50/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0014 - mae: 0.0291 - mape: 2.2824

# %%
transformer_predictions = transformer_model.predict(etl_data.X_test)
mse = mean_squared_error(test_targets, transformer_predictions[:1015])
mae = mean_absolute_error(test_targets, transformer_predictions[:1015])
rmse = mean_squared_error(test_targets, transformer_predictions[:1015], squared=False)
print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# 32/32 [==============================] - 1s 22ms/step
# Mean Squared Error: 0.4146265251861313
# Mean Absolute Error: 0.4125690744934033
# Root Mean Squared Error: 0.4151669836252273

# %% [markdown]
# ## Visualizations

# %%
def plot_results(test, preds, df, image_path=None, title_suffix=None, xlabel='EURUSD price'):
  """
  Plots training data in blue, actual values in red, and predictions in green,
  over time.
  """
  fig, ax = plt.subplots(figsize=(20,6))

  plot_test = test[1:]
  plot_preds = preds[1:]
  x = df[-(plot_test.shape[0]*plot_test.shape[1]):].index
  plot_test = plot_test.reshape((plot_test.shape[0]*plot_test.shape[1], 1))
  plot_preds = plot_preds.reshape((plot_test.shape[0]*plot_test.shape[1], 1))
  ax.plot(x, plot_test, label='actual')
  ax.plot(x, plot_preds, label='preds')

  if title_suffix==None:
    ax.set_title('Predictions vs. Actual')
  else:
    ax.set_title(f'Predictions vs. Actual, {title_suffix}')

  ax.set_xlabel('Date')
  ax.set_ylabel(xlabel)
  ax.legend()
  if image_path != None:
    imagedir = './result_plots'
    plt.savefig(f'{imagedir}/{image_path}.png')
  plt.show()

# %% [markdown]
# ### NBits

# %%
plot_results(etl_data.X_test[:1015], predictions_nbits, etl_data.df, title_suffix='NBits')

# %% [markdown]
# ### NHeats

# %%
plot_results(etl_data.X_test[:1015], nhits_predictions, etl_data.df, title_suffix='LSTM')

# %% [markdown]
# ### LSTM

# %%
plot_results(etl_data.X_test[:1015], lstm_predictions, etl_data.df, title_suffix='LSTM')

# %% [markdown]
# ## RNN

# %%
plot_results(etl_data.X_test[:1015], predictions_rnn, etl_data.df, title_suffix='RNN')

# %% [markdown]
# ### Transformer

# %%
plot_results(etl_data.X_test, transformer_predictions, etl_data.df, title_suffix='Transformer')

# %% [markdown]
# Save and serialize models for the bot

# %%
# save models for bot usage
nbeats_model.save('./model_dumps/nbeats.keras')
nhits_model.save('./model_dumps/nhits.keras')
rnn_model.save('./model_dumps/rnn.keras')
lstm_model.save('./model_dumps/lstm.keras')
transformer_model.save('./model_dumps/transformer.keras')
