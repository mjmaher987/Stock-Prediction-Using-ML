# %% [markdown]
# <a href="https://colab.research.google.com/github/mjmaher987/Stock-Prediction-Using-ML/blob/main/Codes/Stock-08302023-0713.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stock Price Prediction

# %% [markdown]
# ## Dependencies

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.layers import Input, Dense, MultiHeadAttention, Reshape, Flatten, LSTM
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# ## Configs

# %%
Configs = {
    "training_percent" : 0.8,
    "window_size" : 5,
    "epoch_number" : 50
}

# %% [markdown]
# ## Preprocessing

# %%
class ETL:
    """
    ticker: str
    period: string
    test_size: float betwee 0 and 1
    n_input: int
    timestep: int
    Extracts data for stock with ticker `ticker` from yf api,
    splits the data into train and test sets by date,
    reshapes the data into np.array of shape [#weeks, 5, 1],
    converts our problem into supervised learning problem.
    """
    def __init__(self, ticker, test_size=0.2, period='max', n_input=5, timestep=5) -> None:
        self.ticker = ticker
        self.period = period
        self.test_size = test_size
        self.n_input = n_input
        self.df = self.extract_historic_data()
        self.timestep = timestep
        self.train, self.test = self.etl()
        self.X_train, self.y_train = self.to_supervised(self.train)
        self.X_test, self.y_test = self.to_supervised(self.test)

    def get_history_from_yf(self):
        t = yf.Ticker(self.ticker)
        return t.history(period=self.period)

    def extract_historic_data(self) -> pd.Series:
        """
        gets historical data from yf api.
        """
        t = yf.Ticker(self.ticker)
        history = t.history(period=self.period)
        return history.Close

    def split_data(self) -> tuple:
        """
        Splits our pd.Series into train and test series with
        test series representing test_size * 100 % of data.
        """
        data = self.extract_historic_data()
        if len(data) != 0:
            train_idx = round(len(data) * (1-self.test_size))
            train = data[:train_idx]
            test = data[train_idx:]
            train = np.array(train)
            test = np.array(test)
            return train[:, np.newaxis], test[:, np.newaxis]
        else:
            raise Exception('Data set is empty, cannot split.')

    def window_and_reshape(self, data) -> np.array:
        """
        Reformats data into shape our model needs,
        namely, [# samples, timestep, # feautures]
        samples
        """
        NUM_FEATURES = 1
        samples = int(data.shape[0] / self.timestep)
        result = np.array(np.array_split(data, samples))
        return result.reshape((samples, self.timestep, NUM_FEATURES))

    def transform(self, train, test) -> np.array:
        train_remainder = train.shape[0] % self.timestep
        test_remainder = test.shape[0] % self.timestep
        if train_remainder != 0 and test_remainder != 0:
            train = train[train_remainder:]
            test = test[test_remainder:]
        elif train_remainder != 0:
            train = train[train_remainder:]
        elif test_remainder != 0:
            test = test[test_remainder:]
        return self.window_and_reshape(train), self.window_and_reshape(test)

    def etl(self) -> tuple[np.array, np.array]:
        """
        Runs complete ETL
        """
        train, test = self.split_data()
        return self.transform(train, test)

    def to_supervised(self, train, n_out=5) -> tuple:
        """
        Converts our time series prediction problem to a
        supervised learning problem.
        """
        # flatted the data
        data = train.reshape((train.shape[0]*train.shape[1], train.shape[2]))
        X, y = [], []
        in_start = 0
        # step over the entire history one time step at a time
        for _ in range(len(data)):
            # define the end of the input sequence
            in_end = in_start + self.n_input
            out_end = in_end + n_out
            # ensure we have enough data for this instance
            if out_end <= len(data):
                x_input = data[in_start:in_end, 0]
                x_input = x_input.reshape((len(x_input), 1))
                X.append(x_input)
                y.append(data[in_end:out_end, 0])
                # move along one time step
                in_start += 1
        return np.array(X), np.array(y)

# %%
etl_data = ETL('EURUSD=X')
history = etl_data.get_history_from_yf()

data = pd.DataFrame(
    {
        'open': pd.Series([x for x in history.Open]),
        'high': pd.Series([x for x in history.High]),
        'low': pd.Series([x for x in history.Low]),
        'close': pd.Series([x for x in history.Close]),
        'volume': pd.Series([x for x in history.Volume]),
    }
)

# Preprocessing
scaler = MinMaxScaler()
data['close'] = scaler.fit_transform(data['close'].values.reshape(-1, 1))

# Splitting into training and testing sets
train_size = int(Configs['training_percent'] * len(data))
train_data, test_data = data[:train_size], data[train_size:]

# %% [markdown]
# ## Experiments

# %% [markdown]
# ###NBEATS

# %%
# Prepare data for N-BEATS
window_size = Configs['window_size']
X, y = [], []
for i in range(len(data) - window_size):
    X.append(data['close'][i:i+window_size])
    y.append(data['close'][i+window_size])
X = np.array(X)
y = np.array(y)

train_size = int(Configs['training_percent']  * len(X))
train_X, test_X = X[:train_size], X[train_size:]
train_y, test_y = y[:train_size], y[train_size:]

# Build N-BEATS model
def build_nbeats(input_shape, output_shape, num_blocks=4, num_neurons=128):
    inputs = Input(shape=input_shape)
    x = inputs
    forecasts = []
    for _ in range(num_blocks):
        for _ in range(4):  # Directly following the N-BEATS architecture
            x = Dense(num_neurons, activation='relu')(x)
        forecast = Dense(output_shape[0])(x)
        forecasts.append(forecast)
    outputs = forecasts[0]  # Use the forecast from the first block as output
    model = Model(inputs, outputs)
    return model

input_shape = (window_size, 1)
output_shape = (1,)
nbeats_model = build_nbeats(input_shape, output_shape)
nbeats_model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Train N-BEATS model
nbeats_model.fit(train_X, train_y, epochs=Configs['epoch_number'] , batch_size=32, verbose=1)

# Make predictions using the trained model
test_predictions = nbeats_model.predict(test_X)
# Out:
# Epoch 1/50
# 128/128 [==============================] - 4s 10ms/step - loss: 0.0481
# Epoch 2/50
# 128/128 [==============================] - 1s 8ms/step - loss: 0.0357
# Epoch 3/50
# 128/128 [==============================] - 1s 8ms/step - loss: 0.0354
# Epoch 4/50
# 128/128 [==============================] - 1s 8ms/step - loss: 0.0352
# Epoch 5/50
# 128/128 [==============================] - 1s 8ms/step - loss: 0.0355
# Epoch 6/50
# 128/128 [==============================] - 1s 10ms/step - loss: 0.0354
# Epoch 7/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.0357
# Epoch 8/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.0353
# Epoch 9/50
# 128/128 [==============================] - 1s 8ms/step - loss: 0.0354
# Epoch 10/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.0352
# Epoch 11/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.0352
# Epoch 12/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.0352
# Epoch 13/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.0354
# Epoch 14/50
# 128/128 [==============================] - 1s 9ms/step - loss: 0.0352
# Epoch 15/50
# 128/128 [==============================] - 1s 7ms/step - loss: 0.0353
# Epoch 16/50
# 128/128 [==============================] - 1s 8ms/step - loss: 0.0352
# Epoch 17/50
# 128/128 [==============================] - 1s 6ms/step - loss: 0.0352
# Epoch 18/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0353
# Epoch 19/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0353
# Epoch 20/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0354
# Epoch 21/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0355
# Epoch 22/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0351
# Epoch 23/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0354
# Epoch 24/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0352
# Epoch 25/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0353
# Epoch 26/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0352
# Epoch 27/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0352
# Epoch 28/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0353
# Epoch 29/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0353
# Epoch 30/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0353
# Epoch 31/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0352
# Epoch 32/50
# 128/128 [==============================] - 1s 6ms/step - loss: 0.0352
# Epoch 33/50
# 128/128 [==============================] - 1s 8ms/step - loss: 0.0351
# Epoch 34/50
# 128/128 [==============================] - 1s 8ms/step - loss: 0.0351
# Epoch 35/50
# 128/128 [==============================] - 1s 7ms/step - loss: 0.0352
# Epoch 36/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0352
# Epoch 37/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0351
# Epoch 38/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0351
# Epoch 39/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0351
# Epoch 40/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0352
# Epoch 41/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0353
# Epoch 42/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0354
# Epoch 43/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0355
# Epoch 44/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0353
# Epoch 45/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0353
# Epoch 46/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0352
# Epoch 47/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0352
# Epoch 48/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0351
# Epoch 49/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0351
# Epoch 50/50
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0351
# 32/32 [==============================] - 0s 2ms/step

# %%
reshaped_test_predictions = test_predictions[:, -1, :]

# %%
mae = mean_absolute_error(test_y, reshaped_test_predictions)
rmse = mean_squared_error(test_y, reshaped_test_predictions, squared=False)
print(f"Mean Absolute Error: {mae}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Mean Absolute Error: 0.22295132387217664
# Root Mean Squared Error: 0.24254503664296698

# %% [markdown]
# ###NHEATS

# %%
X = data[['open', 'high', 'low', 'volume']].values
y = data['close'].values

train_size = int(0.7 * len(X))
val_size = int(0.15 * len(X))
train_X, test_X, train_y, test_y = X[:train_size], X[train_size:], y[:train_size], y[train_size:]
train_X, val_X, train_y, val_y = train_X[:train_size - val_size], train_X[train_size - val_size:], \
                                  train_y[:train_size - val_size], train_y[train_size - val_size:]

# Normalize data
scaler_X = MinMaxScaler()
train_X = scaler_X.fit_transform(train_X)
val_X = scaler_X.transform(val_X)
test_X = scaler_X.transform(test_X)

scaler_y = MinMaxScaler()
train_y = scaler_y.fit_transform(train_y.reshape(-1, 1)).flatten()
val_y = scaler_y.transform(val_y.reshape(-1, 1)).flatten()
test_y = scaler_y.transform(test_y.reshape(-1, 1)).flatten()

# NHITS Model
def build_nhits(input_shape):
    model = tf.keras.Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dense(64, activation='relu'),
        Dense(1)
    ])
    return model

nhits_model = build_nhits(train_X.shape[1])
nhits_model.compile(optimizer='adam', loss='mean_squared_error')

nhits_model.fit(train_X, train_y, epochs=Configs['epoch_number'], batch_size=32, validation_data=(val_X, val_y), verbose=1)

nhits_predictions = nhits_model.predict(test_X)

# Calculate MAE and RMSE for NHITS
nhits_mae = mean_absolute_error(test_y, nhits_predictions)
nhits_rmse = mean_squared_error(test_y, nhits_predictions, squared=False)
print(f"NHITS Mean Absolute Error: {nhits_mae}")
print(f"NHITS Root Mean Squared Error: {nhits_rmse}")
# Out:
# Epoch 1/50
# 89/89 [==============================] - 1s 5ms/step - loss: 0.0272 - val_loss: 0.0148
# Epoch 2/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.8088e-04 - val_loss: 0.0121
# Epoch 3/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6552e-04 - val_loss: 0.0104
# Epoch 4/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6189e-04 - val_loss: 0.0090
# Epoch 5/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6716e-04 - val_loss: 0.0079
# Epoch 6/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6425e-04 - val_loss: 0.0094
# Epoch 7/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6633e-04 - val_loss: 0.0083
# Epoch 8/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6315e-04 - val_loss: 0.0078
# Epoch 9/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6823e-04 - val_loss: 0.0096
# Epoch 10/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.7364e-04 - val_loss: 0.0081
# Epoch 11/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.6466e-04 - val_loss: 0.0072
# Epoch 12/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6285e-04 - val_loss: 0.0066
# Epoch 13/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.7597e-04 - val_loss: 0.0070
# Epoch 14/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.6206e-04 - val_loss: 0.0067
# Epoch 15/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.6003e-04 - val_loss: 0.0074
# Epoch 16/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6387e-04 - val_loss: 0.0058
# Epoch 17/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.5680e-04 - val_loss: 0.0068
# Epoch 18/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6980e-04 - val_loss: 0.0068
# Epoch 19/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.5907e-04 - val_loss: 0.0057
# Epoch 20/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6016e-04 - val_loss: 0.0070
# Epoch 21/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6725e-04 - val_loss: 0.0069
# Epoch 22/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.5709e-04 - val_loss: 0.0074
# Epoch 23/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6166e-04 - val_loss: 0.0062
# Epoch 24/50
# 89/89 [==============================] - 0s 4ms/step - loss: 1.5471e-04 - val_loss: 0.0076
# Epoch 25/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6615e-04 - val_loss: 0.0070
# Epoch 26/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.5757e-04 - val_loss: 0.0069
# Epoch 27/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6095e-04 - val_loss: 0.0075
# Epoch 28/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.6480e-04 - val_loss: 0.0071
# Epoch 29/50
# 89/89 [==============================] - 1s 13ms/step - loss: 1.6122e-04 - val_loss: 0.0061
# Epoch 30/50
# 89/89 [==============================] - 0s 4ms/step - loss: 1.6272e-04 - val_loss: 0.0080
# Epoch 31/50
# 89/89 [==============================] - 1s 10ms/step - loss: 1.5624e-04 - val_loss: 0.0063
# Epoch 32/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.6304e-04 - val_loss: 0.0071
# Epoch 33/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.5927e-04 - val_loss: 0.0079
# Epoch 34/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.5862e-04 - val_loss: 0.0069
# Epoch 35/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.7277e-04 - val_loss: 0.0075
# Epoch 36/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.6295e-04 - val_loss: 0.0071
# Epoch 37/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.5595e-04 - val_loss: 0.0070
# Epoch 38/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.7807e-04 - val_loss: 0.0077
# Epoch 39/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.7195e-04 - val_loss: 0.0073
# Epoch 40/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.5701e-04 - val_loss: 0.0071
# Epoch 41/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.5619e-04 - val_loss: 0.0077
# Epoch 42/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.5986e-04 - val_loss: 0.0075
# Epoch 43/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.5782e-04 - val_loss: 0.0082
# Epoch 44/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.6669e-04 - val_loss: 0.0082
# Epoch 45/50
# 89/89 [==============================] - 0s 3ms/step - loss: 1.5897e-04 - val_loss: 0.0067
# Epoch 46/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.6286e-04 - val_loss: 0.0080
# Epoch 47/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.7252e-04 - val_loss: 0.0089
# Epoch 48/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.6410e-04 - val_loss: 0.0093
# Epoch 49/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.7761e-04 - val_loss: 0.0078
# Epoch 50/50
# 89/89 [==============================] - 0s 2ms/step - loss: 1.5863e-04 - val_loss: 0.0087
# 49/49 [==============================] - 0s 2ms/step
# NHITS Mean Absolute Error: 0.0669981090445355
# NHITS Root Mean Squared Error: 0.10339961750019722

# %% [markdown]
# ###RNN

# %%
# RNN Model
def build_rnn(input_shape):
    model = tf.keras.Sequential([
        tf.keras.layers.LSTM(64, input_shape=(input_shape, 1), activation='relu'),
        tf.keras.layers.Dense(1)
    ])
    return model

train_X_rnn = train_X.reshape(train_X.shape[0], train_X.shape[1], 1)
val_X_rnn = val_X.reshape(val_X.shape[0], val_X.shape[1], 1)
test_X_rnn = test_X.reshape(test_X.shape[0], test_X.shape[1], 1)

rnn_model = build_rnn(train_X_rnn.shape[1])
rnn_model.compile(optimizer='adam', loss='mean_squared_error')

rnn_model.fit(train_X_rnn, train_y, epochs=Configs['epoch_number'], batch_size=32, validation_data=(val_X_rnn, val_y), verbose=1)


# Evaluate RNN models
rnn_predictions = rnn_model.predict(test_X_rnn)
print(test_X_rnn)

# Calculate MAE and RMSE for RNN
rnn_mae = mean_absolute_error(test_y, rnn_predictions)
rnn_rmse = mean_squared_error(test_y, rnn_predictions, squared=False)
print(f"RNN Mean Absolute Error: {rnn_mae}")
print(f"RNN Root Mean Squared Error: {rnn_rmse}")
# Out:
# Epoch 1/50
# 89/89 [==============================] - 2s 7ms/step - loss: 0.0566 - val_loss: 0.1195
# Epoch 2/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0494
# Epoch 3/50
# 89/89 [==============================] - 0s 5ms/step - loss: 5.2492e-04 - val_loss: 0.0256
# Epoch 4/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.3884e-04 - val_loss: 0.0193
# Epoch 5/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.1425e-04 - val_loss: 0.0160
# Epoch 6/50
# 89/89 [==============================] - 1s 6ms/step - loss: 2.1288e-04 - val_loss: 0.0146
# Epoch 7/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9997e-04 - val_loss: 0.0135
# Epoch 8/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9752e-04 - val_loss: 0.0119
# Epoch 9/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9970e-04 - val_loss: 0.0114
# Epoch 10/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9666e-04 - val_loss: 0.0104
# Epoch 11/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.0033e-04 - val_loss: 0.0110
# Epoch 12/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.0351e-04 - val_loss: 0.0101
# Epoch 13/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.1403e-04 - val_loss: 0.0096
# Epoch 14/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9948e-04 - val_loss: 0.0100
# Epoch 15/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9621e-04 - val_loss: 0.0100
# Epoch 16/50
# 89/89 [==============================] - 1s 6ms/step - loss: 1.9782e-04 - val_loss: 0.0099
# Epoch 17/50
# 89/89 [==============================] - 1s 9ms/step - loss: 2.0313e-04 - val_loss: 0.0093
# Epoch 18/50
# 89/89 [==============================] - 1s 13ms/step - loss: 1.9398e-04 - val_loss: 0.0100
# Epoch 19/50
# 89/89 [==============================] - 1s 12ms/step - loss: 2.0231e-04 - val_loss: 0.0090
# Epoch 20/50
# 89/89 [==============================] - 1s 15ms/step - loss: 1.9171e-04 - val_loss: 0.0089
# Epoch 21/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9519e-04 - val_loss: 0.0093
# Epoch 22/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9460e-04 - val_loss: 0.0095
# Epoch 23/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9555e-04 - val_loss: 0.0089
# Epoch 24/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.1336e-04 - val_loss: 0.0096
# Epoch 25/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.0158e-04 - val_loss: 0.0096
# Epoch 26/50
# 89/89 [==============================] - 0s 4ms/step - loss: 1.9466e-04 - val_loss: 0.0091
# Epoch 27/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9429e-04 - val_loss: 0.0088
# Epoch 28/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.0264e-04 - val_loss: 0.0099
# Epoch 29/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.0685e-04 - val_loss: 0.0093
# Epoch 30/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.0859e-04 - val_loss: 0.0101
# Epoch 31/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.1860e-04 - val_loss: 0.0097
# Epoch 32/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.0961e-04 - val_loss: 0.0094
# Epoch 33/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9319e-04 - val_loss: 0.0089
# Epoch 34/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.0840e-04 - val_loss: 0.0094
# Epoch 35/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9679e-04 - val_loss: 0.0089
# Epoch 36/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.2055e-04 - val_loss: 0.0096
# Epoch 37/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9372e-04 - val_loss: 0.0096
# Epoch 38/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9669e-04 - val_loss: 0.0095
# Epoch 39/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.0716e-04 - val_loss: 0.0100
# Epoch 40/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9378e-04 - val_loss: 0.0089
# Epoch 41/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.0712e-04 - val_loss: 0.0092
# Epoch 42/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.8727e-04 - val_loss: 0.0090
# Epoch 43/50
# 89/89 [==============================] - 0s 6ms/step - loss: 1.8965e-04 - val_loss: 0.0087
# Epoch 44/50
# 89/89 [==============================] - 1s 7ms/step - loss: 1.8915e-04 - val_loss: 0.0088
# Epoch 45/50
# 89/89 [==============================] - 1s 7ms/step - loss: 1.8986e-04 - val_loss: 0.0087
# Epoch 46/50
# 89/89 [==============================] - 1s 6ms/step - loss: 1.8935e-04 - val_loss: 0.0090
# Epoch 47/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.0830e-04 - val_loss: 0.0088
# Epoch 48/50
# 89/89 [==============================] - 1s 6ms/step - loss: 1.9761e-04 - val_loss: 0.0085
# Epoch 49/50
# 89/89 [==============================] - 0s 5ms/step - loss: 2.0388e-04 - val_loss: 0.0091
# Epoch 50/50
# 89/89 [==============================] - 0s 5ms/step - loss: 1.9923e-04 - val_loss: 0.0088
# 49/49 [==============================] - 0s 2ms/step
# [[[ 0.01902691]
#   [ 0.01116227]
#   [ 0.72464986]
#   [ 0.        ]]
#
#  [[ 0.00904997]
#   [ 0.00157079]
#   [ 0.72250323]
#   [ 0.        ]]
#
#  [[ 0.01575717]
#   [ 0.00439632]
#   [ 0.72578213]
#   [ 0.        ]]
#
#  ...
#
#  [[-0.20377593]
#   [-0.21196656]
#   [ 0.6649288 ]
#   [ 0.        ]]
#
#  [[-0.19723508]
#   [-0.20373554]
#   [ 0.66388304]
#   [ 0.        ]]
#
#  [[-0.18372047]
#   [-0.19633389]
#   [ 0.66940775]
#   [ 0.        ]]]
# RNN Mean Absolute Error: 0.06699917128819344
# RNN Root Mean Squared Error: 0.09747365958546339

# %% [markdown]
# ###LSTM

# %%
# LSTM Model
def build_lstm(input_shape):
    model = tf.keras.Sequential([
        LSTM(64, input_shape=input_shape, activation='relu', return_sequences=True),
        LSTM(32, activation='relu'),
        Dense(1)
    ])
    return model

train_X_lstm = train_X.reshape(train_X.shape[0], train_X.shape[1], 1)
test_X_lstm = test_X.reshape(test_X.shape[0], test_X.shape[1], 1)

lstm_model = build_lstm(train_X_lstm.shape[1:])
lstm_model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

lstm_model.fit(train_X_lstm, train_y, epochs=Configs['epoch_number'], batch_size=32, verbose=1)

lstm_predictions = lstm_model.predict(test_X_lstm)


# Calculate MAE and RMSE for LSTM
lstm_mae = mean_absolute_error(test_y, lstm_predictions)
lstm_rmse = mean_squared_error(test_y, lstm_predictions, squared=False)
print(f"LSTM Mean Absolute Error: {lstm_mae}")
print(f"LSTM Root Mean Squared Error: {lstm_rmse}")
# Out:
# Epoch 1/50
# 89/89 [==============================] - 4s 7ms/step - loss: 0.0711
# Epoch 2/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0038
# Epoch 3/50
# 89/89 [==============================] - 1s 7ms/step - loss: 9.1490e-04
# Epoch 4/50
# 89/89 [==============================] - 1s 9ms/step - loss: 3.1453e-04
# Epoch 5/50
# 89/89 [==============================] - 1s 10ms/step - loss: 2.3896e-04
# Epoch 6/50
# 89/89 [==============================] - 1s 10ms/step - loss: 2.3208e-04
# Epoch 7/50
# 89/89 [==============================] - 1s 10ms/step - loss: 2.1206e-04
# Epoch 8/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.1235e-04
# Epoch 9/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.1243e-04
# Epoch 10/50
# 89/89 [==============================] - 1s 7ms/step - loss: 1.9625e-04
# Epoch 11/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.0290e-04
# Epoch 12/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.0002e-04
# Epoch 13/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.0776e-04
# Epoch 14/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.1516e-04
# Epoch 15/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.4754e-04
# Epoch 16/50
# 89/89 [==============================] - 1s 7ms/step - loss: 1.9995e-04
# Epoch 17/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.3493e-04
# Epoch 18/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.0020e-04
# Epoch 19/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.0337e-04
# Epoch 20/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.0987e-04
# Epoch 21/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.1333e-04
# Epoch 22/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.1920e-04
# Epoch 23/50
# 89/89 [==============================] - 1s 8ms/step - loss: 2.2429e-04
# Epoch 24/50
# 89/89 [==============================] - 1s 10ms/step - loss: 1.9356e-04
# Epoch 25/50
# 89/89 [==============================] - 1s 10ms/step - loss: 1.9820e-04
# Epoch 26/50
# 89/89 [==============================] - 1s 10ms/step - loss: 2.1129e-04
# Epoch 27/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.1278e-04
# Epoch 28/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.2751e-04
# Epoch 29/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.0863e-04
# Epoch 30/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.0061e-04
# Epoch 31/50
# 89/89 [==============================] - 1s 7ms/step - loss: 1.9543e-04
# Epoch 32/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.0680e-04
# Epoch 33/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.0582e-04
# Epoch 34/50
# 89/89 [==============================] - 1s 7ms/step - loss: 1.9759e-04
# Epoch 35/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.1306e-04
# Epoch 36/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.1057e-04
# Epoch 37/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.1176e-04
# Epoch 38/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.0443e-04
# Epoch 39/50
# 89/89 [==============================] - 1s 7ms/step - loss: 1.9717e-04
# Epoch 40/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.0444e-04
# Epoch 41/50
# 89/89 [==============================] - 1s 7ms/step - loss: 1.9880e-04
# Epoch 42/50
# 89/89 [==============================] - 1s 6ms/step - loss: 2.2441e-04
# Epoch 43/50
# 89/89 [==============================] - 1s 9ms/step - loss: 2.2621e-04
# Epoch 44/50
# 89/89 [==============================] - 1s 10ms/step - loss: 1.9809e-04
# Epoch 45/50
# 89/89 [==============================] - 1s 10ms/step - loss: 2.0404e-04
# Epoch 46/50
# 89/89 [==============================] - 1s 10ms/step - loss: 2.3368e-04
# Epoch 47/50
# 89/89 [==============================] - 1s 7ms/step - loss: 1.9786e-04
# Epoch 48/50
# 89/89 [==============================] - 1s 7ms/step - loss: 1.9882e-04
# Epoch 49/50
# 89/89 [==============================] - 1s 7ms/step - loss: 3.6689e-04
# Epoch 50/50
# 89/89 [==============================] - 1s 7ms/step - loss: 2.1933e-04
# 49/49 [==============================] - 0s 3ms/step
# LSTM Mean Absolute Error: 0.06465857674061717
# LSTM Root Mean Squared Error: 0.09679649728506308

# %%
print(test_X_lstm)
# Out:
# [[[ 0.01902691]
#   [ 0.01116227]
#   [ 0.72464986]
#   [ 0.        ]]
#
#  [[ 0.00904997]
#   [ 0.00157079]
#   [ 0.72250323]
#   [ 0.        ]]
#
#  [[ 0.01575717]
#   [ 0.00439632]
#   [ 0.72578213]
#   [ 0.        ]]
#
#  ...
#
#  [[-0.20377593]
#   [-0.21196656]
#   [ 0.6649288 ]
#   [ 0.        ]]
#
#  [[-0.19723508]
#   [-0.20373554]
#   [ 0.66388304]
#   [ 0.        ]]
#
#  [[-0.18372047]
#   [-0.19633389]
#   [ 0.66940775]
#   [ 0.        ]]]

# %% [markdown]
# ###Transformers

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0, epsilon=1e-6, attention_axes=None, kernel_size=1):
  """
  Creates a single transformer block.
  """
  x = layers.LayerNormalization(epsilon=epsilon)(inputs)
  x = layers.MultiHeadAttention(
      key_dim=head_size, num_heads=num_heads, dropout=dropout,
      attention_axes=attention_axes
      )(x, x)
  x = layers.Dropout(dropout)(x)
  res = x + inputs

    # Feed Forward Part
  x = layers.LayerNormalization(epsilon=epsilon)(res)
  x = layers.Conv1D(filters=ff_dim, kernel_size=kernel_size, activation="relu")(x)
  x = layers.Dropout(dropout)(x)
  x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=kernel_size)(x)
  return x + res

def build_transfromer(head_size, num_heads, ff_dim, num_trans_blocks, mlp_units, dropout=0, mlp_dropout=0, attention_axes=None, epsilon=1e-6, kernel_size=1):
  """
  Creates final model by building many transformer blocks.
  """
  n_timesteps, n_features, n_outputs = 5, 1, 5
  inputs = tf.keras.Input(shape=(n_timesteps, n_features))
  x = inputs
  for _ in range(num_trans_blocks):
    x = transformer_encoder(x, head_size=head_size, num_heads=num_heads, ff_dim=ff_dim, dropout=dropout, attention_axes=attention_axes, kernel_size=kernel_size, epsilon=epsilon)

  x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
  for dim in mlp_units:
    x = layers.Dense(dim, activation="relu")(x)
    x = layers.Dropout(mlp_dropout)(x)

  outputs = layers.Dense(n_outputs)(x)
  return tf.keras.Model(inputs, outputs)


transformer_model = build_transfromer(head_size=128, num_heads=4, ff_dim=2, num_trans_blocks=4, mlp_units=[256], mlp_dropout=0.10, dropout=0.10, attention_axes=1)

def fit_transformer(transformer: tf.keras.Model):
  """
  Compiles and fits our transformer.
  """
  transformer.compile(
    loss="mse",
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    metrics=["mae", 'mape'])

  callbacks = [tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)]
  hist = transformer.fit(etl_data.X_train, etl_data.y_train, batch_size=32, epochs=Configs['epoch_number'], verbose=1, callbacks=callbacks)
  return hist


hist = fit_transformer(transformer_model)
# Out:
# Epoch 1/50
# 128/128 [==============================] - 13s 27ms/step - loss: 0.1004 - mae: 0.2016 - mape: 15.8851
# Epoch 2/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0132 - mae: 0.0905 - mape: 7.1455
# Epoch 3/50
# 128/128 [==============================] - 4s 31ms/step - loss: 0.0085 - mae: 0.0728 - mape: 5.7432
# Epoch 4/50
# 128/128 [==============================] - 4s 31ms/step - loss: 0.0072 - mae: 0.0666 - mape: 5.2450
# Epoch 5/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0063 - mae: 0.0627 - mape: 4.9296
# Epoch 6/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0060 - mae: 0.0613 - mape: 4.8261
# Epoch 7/50
# 128/128 [==============================] - 5s 36ms/step - loss: 0.0054 - mae: 0.0577 - mape: 4.5410
# Epoch 8/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0052 - mae: 0.0567 - mape: 4.4520
# Epoch 9/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0050 - mae: 0.0557 - mape: 4.3893
# Epoch 10/50
# 128/128 [==============================] - 5s 42ms/step - loss: 0.0044 - mae: 0.0527 - mape: 4.1544
# Epoch 11/50
# 128/128 [==============================] - 4s 30ms/step - loss: 0.0044 - mae: 0.0524 - mape: 4.1243
# Epoch 12/50
# 128/128 [==============================] - 4s 27ms/step - loss: 0.0041 - mae: 0.0506 - mape: 3.9774
# Epoch 13/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0040 - mae: 0.0498 - mape: 3.9170
# Epoch 14/50
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0037 - mae: 0.0483 - mape: 3.7996
# Epoch 15/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0035 - mae: 0.0471 - mape: 3.7093
# Epoch 16/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0034 - mae: 0.0463 - mape: 3.6494
# Epoch 17/50
# 128/128 [==============================] - 4s 33ms/step - loss: 0.0032 - mae: 0.0447 - mape: 3.5132
# Epoch 18/50
# 128/128 [==============================] - 4s 30ms/step - loss: 0.0033 - mae: 0.0453 - mape: 3.5632
# Epoch 19/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0031 - mae: 0.0441 - mape: 3.4697
# Epoch 20/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0030 - mae: 0.0432 - mape: 3.3882
# Epoch 21/50
# 128/128 [==============================] - 5s 35ms/step - loss: 0.0028 - mae: 0.0422 - mape: 3.3240
# Epoch 22/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0027 - mae: 0.0411 - mape: 3.2359
# Epoch 23/50
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0027 - mae: 0.0410 - mape: 3.2207
# Epoch 24/50
# 128/128 [==============================] - 5s 36ms/step - loss: 0.0027 - mae: 0.0407 - mape: 3.2021
# Epoch 25/50
# 128/128 [==============================] - 4s 29ms/step - loss: 0.0024 - mae: 0.0392 - mape: 3.0870
# Epoch 26/50
# 128/128 [==============================] - 4s 30ms/step - loss: 0.0025 - mae: 0.0397 - mape: 3.1186
# Epoch 27/50
# 128/128 [==============================] - 4s 34ms/step - loss: 0.0024 - mae: 0.0389 - mape: 3.0571
# Epoch 28/50
# 128/128 [==============================] - 4s 33ms/step - loss: 0.0024 - mae: 0.0391 - mape: 3.0767
# Epoch 29/50
# 128/128 [==============================] - 4s 28ms/step - loss: 0.0023 - mae: 0.0379 - mape: 2.9767
# Epoch 30/50
# 128/128 [==============================] - 4s 31ms/step - loss: 0.0023 - mae: 0.0377 - mape: 2.9609
# Epoch 31/50
# 128/128 [==============================] - 5s 36ms/step - loss: 0.0023 - mae: 0.0375 - mape: 2.9493
# Epoch 32/50
# 128/128 [==============================] - 4s 30ms/step - loss: 0.0021 - mae: 0.0362 - mape: 2.8471
# Epoch 33/50
# 128/128 [==============================] - 4s 29ms/step - loss: 0.0021 - mae: 0.0359 - mape: 2.8228
# Epoch 34/50
# 128/128 [==============================] - 5s 38ms/step - loss: 0.0020 - mae: 0.0352 - mape: 2.7657
# Epoch 35/50
# 128/128 [==============================] - 4s 28ms/step - loss: 0.0020 - mae: 0.0353 - mape: 2.7707
# Epoch 36/50
# 128/128 [==============================] - 4s 30ms/step - loss: 0.0019 - mae: 0.0343 - mape: 2.6964
# Epoch 37/50
# 128/128 [==============================] - 5s 38ms/step - loss: 0.0019 - mae: 0.0341 - mape: 2.6799
# Epoch 38/50
# 128/128 [==============================] - 4s 29ms/step - loss: 0.0018 - mae: 0.0331 - mape: 2.5970
# Epoch 39/50
# 128/128 [==============================] - 4s 29ms/step - loss: 0.0019 - mae: 0.0344 - mape: 2.6982
# Epoch 40/50
# 128/128 [==============================] - 5s 38ms/step - loss: 0.0016 - mae: 0.0320 - mape: 2.5114
# Epoch 41/50
# 128/128 [==============================] - 4s 29ms/step - loss: 0.0017 - mae: 0.0330 - mape: 2.5946
# Epoch 42/50
# 128/128 [==============================] - 4s 27ms/step - loss: 0.0016 - mae: 0.0314 - mape: 2.4658
# Epoch 43/50
# 128/128 [==============================] - 5s 37ms/step - loss: 0.0016 - mae: 0.0313 - mape: 2.4481
# Epoch 44/50
# 128/128 [==============================] - 4s 32ms/step - loss: 0.0016 - mae: 0.0319 - mape: 2.5001
# Epoch 45/50
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0015 - mae: 0.0299 - mape: 2.3409
# Epoch 46/50
# 128/128 [==============================] - 4s 30ms/step - loss: 0.0015 - mae: 0.0300 - mape: 2.3570
# Epoch 47/50
# 128/128 [==============================] - 5s 36ms/step - loss: 0.0014 - mae: 0.0300 - mape: 2.3528
# Epoch 48/50
# 128/128 [==============================] - 4s 29ms/step - loss: 0.0014 - mae: 0.0291 - mape: 2.2789
# Epoch 49/50
# 128/128 [==============================] - 4s 30ms/step - loss: 0.0014 - mae: 0.0289 - mape: 2.2619
# Epoch 50/50
# 128/128 [==============================] - 5s 37ms/step - loss: 0.0013 - mae: 0.0284 - mape: 2.2193

# %%
transformer_predictions = transformer_model.predict(etl_data.X_test)
for d in etl_data.X_test:
    print(d)

transformer_mae = mean_absolute_error(etl_data.y_test, transformer_predictions)
transformer_rmse = mean_squared_error(etl_data.y_test, transformer_predictions, squared=False)
print(f"Transformer Mean Absolute Error: {transformer_mae}")
print(f"Transformet Mean Squared Error: {transformer_rmse}")
# Out:
# Streaming output truncated to the last 5000 lines.
#  [1.11517537]
#  [1.11292887]
#  [1.11323857]]
# [[1.11557341]
#  [1.11517537]
#  [1.11292887]
#  [1.11323857]
#  [1.11039555]]
# [[1.11517537]
#  [1.11292887]
#  [1.11323857]
#  [1.11039555]
#  [1.10842621]]
# [[1.11292887]
#  [1.11323857]
#  [1.11039555]
#  [1.10842621]
#  [1.1099149 ]]
# [[1.11323857]
#  [1.11039555]
#  [1.10842621]
#  [1.1099149 ]
#  [1.11148167]]
# [[1.11039555]
#  [1.10842621]
#  [1.1099149 ]
#  [1.11148167]
#  [1.11544895]]
# [[1.10842621]
#  [1.1099149 ]
#  [1.11148167]
#  [1.11544895]
#  [1.11571026]]
# [[1.1099149 ]
#  [1.11148167]
#  [1.11544895]
#  [1.11571026]
#  [1.11665714]]
# [[1.11148167]
#  [1.11544895]
#  [1.11571026]
#  [1.11665714]
#  [1.1128546 ]]
# [[1.11544895]
#  [1.11571026]
#  [1.11665714]
#  [1.1128546 ]
#  [1.10741973]]
# [[1.11571026]
#  [1.11665714]
#  [1.1128546 ]
#  [1.10741973]
#  [1.10703969]]
# [[1.11665714]
#  [1.1128546 ]
#  [1.10741973]
#  [1.10703969]
#  [1.10196972]]
# [[1.1128546 ]
#  [1.10741973]
#  [1.10703969]
#  [1.10196972]
#  [1.10224426]]
# [[1.10741973]
#  [1.10703969]
#  [1.10196972]
#  [1.10224426]
#  [1.10354567]]
# [[1.10703969]
#  [1.10196972]
#  [1.10224426]
#  [1.10354567]
#  [1.1012367 ]]
# [[1.10196972]
#  [1.10224426]
#  [1.10354567]
#  [1.1012367 ]
#  [1.10132158]]
# [[1.10224426]
#  [1.10354567]
#  [1.1012367 ]
#  [1.10132158]
#  [1.10204983]]
# [[1.10354567]
#  [1.1012367 ]
#  [1.10132158]
#  [1.10204983]
#  [1.10550988]]
# [[1.1012367 ]
#  [1.10132158]
#  [1.10204983]
#  [1.10550988]
#  [1.10723579]]
# [[1.10132158]
#  [1.10204983]
#  [1.10550988]
#  [1.10723579]
#  [1.10800016]]
# [[1.10204983]
#  [1.10550988]
#  [1.10723579]
#  [1.10800016]
#  [1.10788596]]
# [[1.10550988]
#  [1.10723579]
#  [1.10800016]
#  [1.10788596]
#  [1.10658634]]
# [[1.10723579]
#  [1.10800016]
#  [1.10788596]
#  [1.10658634]
#  [1.1022563 ]]
# [[1.10800016]
#  [1.10788596]
#  [1.10658634]
#  [1.1022563 ]
#  [1.10144293]]
# [[1.10788596]
#  [1.10658634]
#  [1.1022563 ]
#  [1.10144293]
#  [1.1022563 ]]
# [[1.10658634]
#  [1.1022563 ]
#  [1.10144293]
#  [1.1022563 ]
#  [1.10048532]]
# [[1.1022563 ]
#  [1.10144293]
#  [1.1022563 ]
#  [1.10048532]
#  [1.10117614]]
# [[1.10144293]
#  [1.1022563 ]
#  [1.10048532]
#  [1.10117614]
#  [1.10190415]]
# [[1.1022563 ]
#  [1.10048532]
#  [1.10117614]
#  [1.10190415]
#  [1.10791051]]
# [[1.10048532]
#  [1.10117614]
#  [1.10190415]
#  [1.10791051]
#  [1.10852456]]
# [[1.10117614]
#  [1.10190415]
#  [1.10791051]
#  [1.10852456]
#  [1.10830343]]
# [[1.10190415]
#  [1.10791051]
#  [1.10852456]
#  [1.10830343]
#  [1.11054349]]
# [[1.10791051]
#  [1.10852456]
#  [1.10830343]
#  [1.11054349]
#  [1.10588884]]
# [[1.10852456]
#  [1.10830343]
#  [1.11054349]
#  [1.10588884]
#  [1.10649943]]
# [[1.10830343]
#  [1.11054349]
#  [1.10588884]
#  [1.10649943]
#  [1.10927463]]
# [[1.11054349]
#  [1.10588884]
#  [1.10649943]
#  [1.10927463]
#  [1.11358571]]
# [[1.10588884]
#  [1.10649943]
#  [1.10927463]
#  [1.11358571]
#  [1.11860573]]
# [[1.10649943]
#  [1.10927463]
#  [1.11358571]
#  [1.11860573]
#  [1.11244607]]
# [[1.10927463]
#  [1.11358571]
#  [1.11860573]
#  [1.11244607]
#  [1.11369741]]
# [[1.11358571]
#  [1.11860573]
#  [1.11244607]
#  [1.11369741]
#  [1.11513805]]
# [[1.11860573]
#  [1.11244607]
#  [1.11369741]
#  [1.11513805]
#  [1.11159277]]
# [[1.11244607]
#  [1.11369741]
#  [1.11513805]
#  [1.11159277]
#  [1.1125946 ]]
# [[1.11369741]
#  [1.11513805]
#  [1.11159277]
#  [1.1125946 ]
#  [1.10798407]]
# [[1.11513805]
#  [1.11159277]
#  [1.1125946 ]
#  [1.10798407]
#  [1.10938537]]
# [[1.11159277]
#  [1.1125946 ]
#  [1.10798407]
#  [1.10938537]
#  [1.1090163 ]]
# [[1.1125946 ]
#  [1.10798407]
#  [1.10938537]
#  [1.1090163 ]
#  [1.10954547]]
# [[1.10798407]
#  [1.10938537]
#  [1.1090163 ]
#  [1.10954547]
#  [1.11011195]]
# [[1.10938537]
#  [1.1090163 ]
#  [1.10954547]
#  [1.11011195]
#  [1.11823046]]
# [[1.1090163 ]
#  [1.10954547]
#  [1.11011195]
#  [1.11823046]
#  [1.12022972]]
# [[1.10954547]
#  [1.11011195]
#  [1.11823046]
#  [1.12022972]
#  [1.12208259]]
# [[1.11011195]
#  [1.11823046]
#  [1.12022972]
#  [1.12208259]
#  [1.12208259]]
# [[1.11823046]
#  [1.12022972]
#  [1.12208259]
#  [1.12208259]
#  [1.11714375]]
# [[1.12022972]
#  [1.12208259]
#  [1.12208259]
#  [1.11714375]
#  [1.11619604]]
# [[1.12208259]
#  [1.12208259]
#  [1.11714375]
#  [1.11619604]
#  [1.11979949]]
# [[1.12208259]
#  [1.11714375]
#  [1.11619604]
#  [1.11979949]
#  [1.11547387]]
# [[1.11714375]
#  [1.11619604]
#  [1.11979949]
#  [1.11547387]
#  [1.11132109]]
# [[1.11619604]
#  [1.11979949]
#  [1.11547387]
#  [1.11132109]
#  [1.11111116]]
# [[1.11979949]
#  [1.11547387]
#  [1.11132109]
#  [1.11111116]
#  [1.11166692]]
# [[1.11547387]
#  [1.11132109]
#  [1.11111116]
#  [1.11166692]
#  [1.11357331]]
# [[1.11132109]
#  [1.11111116]
#  [1.11166692]
#  [1.11357331]
#  [1.11308992]]
# [[1.11111116]
#  [1.11166692]
#  [1.11357331]
#  [1.11308992]
#  [1.11540043]]
# [[1.11166692]
#  [1.11357331]
#  [1.11308992]
#  [1.11540043]
#  [1.11395788]]
# [[1.11357331]
#  [1.11308992]
#  [1.11540043]
#  [1.11395788]
#  [1.10945928]]
# [[1.11308992]
#  [1.11540043]
#  [1.11395788]
#  [1.10945928]
#  [1.10969317]]
# [[1.11540043]
#  [1.11395788]
#  [1.10945928]
#  [1.10969317]
#  [1.1085614 ]]
# [[1.11395788]
#  [1.10945928]
#  [1.10969317]
#  [1.1085614 ]
#  [1.10964394]]
# [[1.10945928]
#  [1.10969317]
#  [1.1085614 ]
#  [1.10964394]
#  [1.10552204]]
# [[1.10969317]
#  [1.1085614 ]
#  [1.10964394]
#  [1.10552204]
#  [1.10253584]]
# [[1.1085614 ]
#  [1.10964394]
#  [1.10552204]
#  [1.10253584]
#  [1.10197699]]
# [[1.10964394]
#  [1.10552204]
#  [1.10253584]
#  [1.10197699]
#  [1.1022563 ]]
# [[1.10552204]
#  [1.10253584]
#  [1.10197699]
#  [1.1022563 ]
#  [1.10168552]]
# [[1.10253584]
#  [1.10197699]
#  [1.1022563 ]
#  [1.10168552]
#  [1.10291278]]
# [[1.10197699]
#  [1.1022563 ]
#  [1.10168552]
#  [1.10291278]
#  [1.10897946]]
# [[1.1022563 ]
#  [1.10168552]
#  [1.10291278]
#  [1.10897946]
#  [1.10629261]]
# [[1.10168552]
#  [1.10291278]
#  [1.10897946]
#  [1.10629261]
#  [1.10472822]]
# [[1.10291278]
#  [1.10897946]
#  [1.10629261]
#  [1.10472822]
#  [1.10023105]]
# [[1.10897946]
#  [1.10629261]
#  [1.10472822]
#  [1.10023105]
#  [1.0982976 ]]
# [[1.10629261]
#  [1.10472822]
#  [1.10023105]
#  [1.0982976 ]
#  [1.09493053]]
# [[1.10472822]
#  [1.10023105]
#  [1.0982976 ]
#  [1.09493053]
#  [1.09134567]]
# [[1.10023105]
#  [1.0982976 ]
#  [1.09493053]
#  [1.09134567]
#  [1.09194148]]
# [[1.0982976 ]
#  [1.09493053]
#  [1.09134567]
#  [1.09194148]
#  [1.08759487]]
# [[1.09493053]
#  [1.09134567]
#  [1.09194148]
#  [1.08759487]
#  [1.08459866]]
# [[1.09134567]
#  [1.09194148]
#  [1.08759487]
#  [1.08459866]
#  [1.08417535]]
# [[1.09194148]
#  [1.08759487]
#  [1.08459866]
#  [1.08417535]
#  [1.08401084]]
# [[1.08759487]
#  [1.08459866]
#  [1.08417535]
#  [1.08401084]
#  [1.07954049]]
# [[1.08459866]
#  [1.08417535]
#  [1.08401084]
#  [1.07954049]
#  [1.08100986]]
# [[1.08417535]
#  [1.08401084]
#  [1.07954049]
#  [1.08100986]
#  [1.07879984]]
# [[1.08401084]
#  [1.07954049]
#  [1.08100986]
#  [1.07879984]
#  [1.0839051 ]]
# [[1.07954049]
#  [1.08100986]
#  [1.07879984]
#  [1.0839051 ]
#  [1.08491993]]
# [[1.08100986]
#  [1.07879984]
#  [1.0839051 ]
#  [1.08491993]
#  [1.08819962]]
# [[1.07879984]
#  [1.0839051 ]
#  [1.08491993]
#  [1.08819962]
#  [1.08858943]]
# [[1.0839051 ]
#  [1.08491993]
#  [1.08819962]
#  [1.08858943]
#  [1.09972286]]
# [[1.08491993]
#  [1.08819962]
#  [1.08858943]
#  [1.09972286]
#  [1.10513115]]
# [[1.08819962]
#  [1.08858943]
#  [1.09972286]
#  [1.10513115]
#  [1.1144048 ]]
# [[1.08858943]
#  [1.09972286]
#  [1.10513115]
#  [1.1144048 ]
#  [1.11806798]]
# [[1.09972286]
#  [1.10513115]
#  [1.1144048 ]
#  [1.11806798]
#  [1.11390829]]
# [[1.10513115]
#  [1.1144048 ]
#  [1.11806798]
#  [1.11390829]
#  [1.12238491]]
# [[1.1144048 ]
#  [1.11806798]
#  [1.11390829]
#  [1.12238491]
#  [1.13860202]]
# [[1.11806798]
#  [1.11390829]
#  [1.12238491]
#  [1.13860202]
#  [1.13979602]]
# [[1.11390829]
#  [1.12238491]
#  [1.13860202]
#  [1.13979602]
#  [1.13165057]]
# [[1.12238491]
#  [1.13860202]
#  [1.13979602]
#  [1.13165057]
#  [1.12615156]]
# [[1.13860202]
#  [1.13979602]
#  [1.13165057]
#  [1.12615156]
#  [1.1184932 ]]
# [[1.13979602]
#  [1.13165057]
#  [1.12615156]
#  [1.1184932 ]
#  [1.11553609]]
# [[1.13165057]
#  [1.12615156]
#  [1.1184932 ]
#  [1.11553609]
#  [1.11632061]]
# [[1.12615156]
#  [1.1184932 ]
#  [1.11553609]
#  [1.11632061]
#  [1.10155213]]
# [[1.1184932 ]
#  [1.11553609]
#  [1.11632061]
#  [1.10155213]
#  [1.09615469]]
# [[1.11553609]
#  [1.11632061]
#  [1.10155213]
#  [1.09615469]
#  [1.06573451]]
# [[1.11632061]
#  [1.10155213]
#  [1.09615469]
#  [1.06573451]
#  [1.0694387 ]]
# [[1.10155213]
#  [1.09615469]
#  [1.06573451]
#  [1.0694387 ]
#  [1.07646108]]
# [[1.09615469]
#  [1.06573451]
#  [1.0694387 ]
#  [1.07646108]
#  [1.08026361]]
# [[1.06573451]
#  [1.0694387 ]
#  [1.07646108]
#  [1.08026361]
#  [1.08895695]]
# [[1.0694387 ]
#  [1.07646108]
#  [1.08026361]
#  [1.08895695]
#  [1.10482585]]
# [[1.07646108]
#  [1.08026361]
#  [1.08895695]
#  [1.10482585]
#  [1.11390829]]
# [[1.08026361]
#  [1.08895695]
#  [1.10482585]
#  [1.11390829]
#  [1.10304666]]
# [[1.08895695]
#  [1.10482585]
#  [1.11390829]
#  [1.10304666]
#  [1.10265744]]
# [[1.10482585]
#  [1.11390829]
#  [1.10304666]
#  [1.10265744]
#  [1.09536219]]
# [[1.11390829]
#  [1.10304666]
#  [1.10265744]
#  [1.09536219]
#  [1.08473992]]
# [[1.10304666]
#  [1.10265744]
#  [1.09536219]
#  [1.08473992]
#  [1.08069551]]
# [[1.10265744]
#  [1.09536219]
#  [1.08473992]
#  [1.08069551]
#  [1.08038032]]
# [[1.09536219]
#  [1.08473992]
#  [1.08069551]
#  [1.08038032]
#  [1.08951449]]
# [[1.08473992]
#  [1.08069551]
#  [1.08038032]
#  [1.08951449]
#  [1.08636618]]
# [[1.08069551]
#  [1.08038032]
#  [1.08951449]
#  [1.08636618]
#  [1.09274089]]
# [[1.08038032]
#  [1.08951449]
#  [1.08636618]
#  [1.09274089]
#  [1.09326661]]
# [[1.08951449]
#  [1.08636618]
#  [1.09274089]
#  [1.09326661]
#  [1.09229934]]
# [[1.08636618]
#  [1.09274089]
#  [1.09326661]
#  [1.09229934]
#  [1.09853888]]
# [[1.09274089]
#  [1.09326661]
#  [1.09229934]
#  [1.09853888]
#  [1.09051013]]
# [[1.09326661]
#  [1.09229934]
#  [1.09853888]
#  [1.09051013]
#  [1.08584714]]
# [[1.09229934]
#  [1.09853888]
#  [1.09051013]
#  [1.08584714]
#  [1.08669662]]
# [[1.09853888]
#  [1.09051013]
#  [1.08584714]
#  [1.08669662]
#  [1.08648407]]
# [[1.09051013]
#  [1.08584714]
#  [1.08669662]
#  [1.08648407]
#  [1.08564675]]
# [[1.08584714]
#  [1.08669662]
#  [1.08648407]
#  [1.08564675]
#  [1.08096421]]
# [[1.08669662]
#  [1.08648407]
#  [1.08564675]
#  [1.08096421]
#  [1.07770228]]
# [[1.08648407]
#  [1.08564675]
#  [1.08096421]
#  [1.07770228]
#  [1.08236825]]
# [[1.08564675]
#  [1.08096421]
#  [1.07770228]
#  [1.08236825]
#  [1.08248544]]
# [[1.08096421]
#  [1.07770228]
#  [1.08236825]
#  [1.08248544]
#  [1.08365846]]
# [[1.07770228]
#  [1.08236825]
#  [1.08248544]
#  [1.08365846]
#  [1.08772504]]
# [[1.08236825]
#  [1.08248544]
#  [1.08365846]
#  [1.08772504]
#  [1.09454691]]
# [[1.08248544]
#  [1.08365846]
#  [1.08772504]
#  [1.09454691]
#  [1.09596252]]
# [[1.08365846]
#  [1.08772504]
#  [1.09454691]
#  [1.09596252]
#  [1.09042931]]
# [[1.08772504]
#  [1.09454691]
#  [1.09596252]
#  [1.09042931]
#  [1.08385813]]
# [[1.09454691]
#  [1.09596252]
#  [1.09042931]
#  [1.08385813]
#  [1.07985532]]
# [[1.09596252]
#  [1.09042931]
#  [1.08385813]
#  [1.07985532]
#  [1.08371711]]
# [[1.09042931]
#  [1.08385813]
#  [1.07985532]
#  [1.08371711]
#  [1.08395207]]
# [[1.08385813]
#  [1.07985532]
#  [1.08371711]
#  [1.08395207]
#  [1.08094084]]
# [[1.07985532]
#  [1.08371711]
#  [1.08395207]
#  [1.08094084]
#  [1.08468103]]
# [[1.08371711]
#  [1.08395207]
#  [1.08094084]
#  [1.08468103]
#  [1.08236825]]
# [[1.08395207]
#  [1.08094084]
#  [1.08468103]
#  [1.08236825]
#  [1.08069551]]
# [[1.08094084]
#  [1.08468103]
#  [1.08236825]
#  [1.08069551]
#  [1.08213401]]
# [[1.08468103]
#  [1.08236825]
#  [1.08069551]
#  [1.08213401]
#  [1.09151244]]
# [[1.08236825]
#  [1.08069551]
#  [1.08213401]
#  [1.09151244]
#  [1.09277678]]
# [[1.08069551]
#  [1.08213401]
#  [1.09151244]
#  [1.09277678]
#  [1.0982976 ]]
# [[1.08213401]
#  [1.09151244]
#  [1.09277678]
#  [1.0982976 ]
#  [1.0952903 ]]
# [[1.09151244]
#  [1.09277678]
#  [1.0982976 ]
#  [1.0952903 ]
#  [1.09078014]]
# [[1.09277678]
#  [1.0982976 ]
#  [1.0952903 ]
#  [1.09078014]
#  [1.09029973]]
# [[1.0982976 ]
#  [1.0952903 ]
#  [1.09078014]
#  [1.09029973]
#  [1.09817708]]
# [[1.0952903 ]
#  [1.09078014]
#  [1.09029973]
#  [1.09817708]
#  [1.10168552]]
# [[1.09078014]
#  [1.09029973]
#  [1.09817708]
#  [1.10168552]
#  [1.10791051]]
# [[1.09029973]
#  [1.09817708]
#  [1.10168552]
#  [1.10791051]
#  [1.11185241]]
# [[1.09817708]
#  [1.10168552]
#  [1.10791051]
#  [1.11185241]
#  [1.1125946 ]]
# [[1.10168552]
#  [1.10791051]
#  [1.11185241]
#  [1.1125946 ]
#  [1.11894369]]
# [[1.10791051]
#  [1.11185241]
#  [1.1125946 ]
#  [1.11894369]
#  [1.12359548]]
# [[1.11185241]
#  [1.1125946 ]
#  [1.11894369]
#  [1.12359548]
#  [1.1337868 ]]
# [[1.1125946 ]
#  [1.11894369]
#  [1.12359548]
#  [1.1337868 ]
#  [1.13195157]]
# [[1.11894369]
#  [1.12359548]
#  [1.1337868 ]
#  [1.13195157]
#  [1.1305567 ]]
# [[1.12359548]
#  [1.1337868 ]
#  [1.13195157]
#  [1.1305567 ]
#  [1.13322151]]
# [[1.1337868 ]
#  [1.13195157]
#  [1.1305567 ]
#  [1.13322151]
#  [1.13654447]]
# [[1.13195157]
#  [1.1305567 ]
#  [1.13322151]
#  [1.13654447]
#  [1.12880826]]
# [[1.1305567 ]
#  [1.13322151]
#  [1.13654447]
#  [1.12880826]
#  [1.12520111]]
# [[1.13322151]
#  [1.13654447]
#  [1.12880826]
#  [1.12520111]
#  [1.13377404]]
# [[1.13654447]
#  [1.12880826]
#  [1.12520111]
#  [1.13377404]
#  [1.12657011]]
# [[1.12880826]
#  [1.12520111]
#  [1.13377404]
#  [1.12657011]
#  [1.12429023]]
# [[1.12520111]
#  [1.13377404]
#  [1.12657011]
#  [1.12429023]
#  [1.12110007]]
# [[1.13377404]
#  [1.12657011]
#  [1.12429023]
#  [1.12110007]
#  [1.11775553]]
# [[1.12657011]
#  [1.12429023]
#  [1.12110007]
#  [1.11775553]
#  [1.12796795]]
# [[1.12429023]
#  [1.12110007]
#  [1.11775553]
#  [1.12796795]
#  [1.13123453]]
# [[1.12110007]
#  [1.11775553]
#  [1.12796795]
#  [1.13123453]
#  [1.12508726]]
# [[1.11775553]
#  [1.12796795]
#  [1.13123453]
#  [1.12508726]
#  [1.12220848]]
# [[1.12796795]
#  [1.13123453]
#  [1.12508726]
#  [1.12220848]
#  [1.12258649]]
# [[1.13123453]
#  [1.12508726]
#  [1.12220848]
#  [1.12258649]
#  [1.12472022]]
# [[1.12508726]
#  [1.12220848]
#  [1.12258649]
#  [1.12472022]
#  [1.12359548]]
# [[1.12220848]
#  [1.12258649]
#  [1.12472022]
#  [1.12359548]
#  [1.12513781]]
# [[1.12258649]
#  [1.12472022]
#  [1.12359548]
#  [1.12513781]
#  [1.1237849 ]]
# [[1.12472022]
#  [1.12359548]
#  [1.12513781]
#  [1.1237849 ]
#  [1.12472022]]
# [[1.12359548]
#  [1.12513781]
#  [1.1237849 ]
#  [1.12472022]
#  [1.13128567]]
# [[1.12513781]
#  [1.1237849 ]
#  [1.12472022]
#  [1.13128567]
#  [1.12752283]]
# [[1.1237849 ]
#  [1.12472022]
#  [1.13128567]
#  [1.12752283]
#  [1.13391542]]
# [[1.12472022]
#  [1.13128567]
#  [1.12752283]
#  [1.13391542]
#  [1.1287955 ]]
# [[1.13128567]
#  [1.12752283]
#  [1.13391542]
#  [1.1287955 ]
#  [1.13100421]]
# [[1.12752283]
#  [1.13391542]
#  [1.1287955 ]
#  [1.13100421]
#  [1.13454962]]
# [[1.13391542]
#  [1.1287955 ]
#  [1.13100421]
#  [1.13454962]
#  [1.14107049]]
# [[1.1287955 ]
#  [1.13100421]
#  [1.13454962]
#  [1.14107049]
#  [1.14171934]]
# [[1.13100421]
#  [1.13454962]
#  [1.14107049]
#  [1.14171934]
#  [1.13921165]]
# [[1.13454962]
#  [1.14107049]
#  [1.14171934]
#  [1.13921165]
#  [1.14429569]]
# [[1.14107049]
#  [1.14171934]
#  [1.13921165]
#  [1.14429569]
#  [1.14586914]]
# [[1.14171934]
#  [1.13921165]
#  [1.14429569]
#  [1.14586914]
#  [1.15340257]]
# [[1.13921165]
#  [1.14429569]
#  [1.14586914]
#  [1.15340257]
#  [1.1568718 ]]
# [[1.14429569]
#  [1.14586914]
#  [1.15340257]
#  [1.1568718 ]
#  [1.15960848]]
# [[1.14586914]
#  [1.15340257]
#  [1.1568718 ]
#  [1.15960848]
#  [1.16525674]]
# [[1.15340257]
#  [1.1568718 ]
#  [1.15960848]
#  [1.16525674]
#  [1.17692757]]
# [[1.1568718 ]
#  [1.15960848]
#  [1.16525674]
#  [1.17692757]
#  [1.17187953]]
# [[1.15960848]
#  [1.16525674]
#  [1.17692757]
#  [1.17187953]
#  [1.17828655]]
# [[1.16525674]
#  [1.17692757]
#  [1.17187953]
#  [1.17828655]
#  [1.18722546]]
# [[1.17692757]
#  [1.17187953]
#  [1.17828655]
#  [1.18722546]
#  [1.178231  ]]
# [[1.17187953]
#  [1.17828655]
#  [1.18722546]
#  [1.178231  ]
#  [1.17633224]]
# [[1.17828655]
#  [1.18722546]
#  [1.178231  ]
#  [1.17633224]
#  [1.1815443 ]]
# [[1.18722546]
#  [1.178231  ]
#  [1.17633224]
#  [1.1815443 ]
#  [1.18728185]]
# [[1.178231  ]
#  [1.17633224]
#  [1.1815443 ]
#  [1.18728185]
#  [1.18764842]]
# [[1.17633224]
#  [1.1815443 ]
#  [1.18728185]
#  [1.18764842]
#  [1.17827272]]
# [[1.1815443 ]
#  [1.18728185]
#  [1.18764842]
#  [1.17827272]
#  [1.17377782]]
# [[1.18728185]
#  [1.18764842]
#  [1.17827272]
#  [1.17377782]
#  [1.17365384]]
# [[1.18764842]
#  [1.17827272]
#  [1.17377782]
#  [1.17365384]
#  [1.17938018]]
# [[1.17827272]
#  [1.17377782]
#  [1.17365384]
#  [1.17938018]
#  [1.18165588]]
# [[1.17377782]
#  [1.17365384]
#  [1.17938018]
#  [1.18165588]
#  [1.18525541]]
# [[1.17365384]
#  [1.17938018]
#  [1.18165588]
#  [1.18525541]
#  [1.18764842]]
# [[1.17938018]
#  [1.18165588]
#  [1.18525541]
#  [1.18764842]
#  [1.19478595]]
# [[1.18165588]
#  [1.18525541]
#  [1.18764842]
#  [1.19478595]
#  [1.18435001]]
# [[1.18525541]
#  [1.18764842]
#  [1.19478595]
#  [1.18435001]
#  [1.18736649]]
# [[1.18764842]
#  [1.19478595]
#  [1.18435001]
#  [1.18736649]
#  [1.17980182]]
# [[1.19478595]
#  [1.18435001]
#  [1.18736649]
#  [1.17980182]
#  [1.17945385]]
# [[1.18435001]
#  [1.18736649]
#  [1.17980182]
#  [1.17945385]
#  [1.18350196]]
# [[1.18736649]
#  [1.17980182]
#  [1.17945385]
#  [1.18350196]
#  [1.18427289]]
# [[1.17980182]
#  [1.17945385]
#  [1.18350196]
#  [1.18427289]
#  [1.18196321]]
# [[1.17945385]
#  [1.18350196]
#  [1.18427289]
#  [1.18196321]
#  [1.19182408]]
# [[1.18350196]
#  [1.18427289]
#  [1.18196321]
#  [1.19182408]
#  [1.19390154]]
# [[1.18427289]
#  [1.18196321]
#  [1.19182408]
#  [1.19390154]
#  [1.19232142]]
# [[1.18196321]
#  [1.19182408]
#  [1.19390154]
#  [1.19232142]
#  [1.18473589]]
# [[1.19182408]
#  [1.19390154]
#  [1.19232142]
#  [1.18473589]
#  [1.18397844]]
# [[1.19390154]
#  [1.19232142]
#  [1.18473589]
#  [1.18397844]
#  [1.18344593]]
# [[1.19232142]
#  [1.18473589]
#  [1.18397844]
#  [1.18344593]
#  [1.18217278]]
# [[1.18473589]
#  [1.18397844]
#  [1.18344593]
#  [1.18217278]
#  [1.17702448]]
# [[1.18397844]
#  [1.18344593]
#  [1.18217278]
#  [1.17702448]
#  [1.1806376 ]]
# [[1.18344593]
#  [1.18217278]
#  [1.17702448]
#  [1.1806376 ]
#  [1.18243849]]
# [[1.18217278]
#  [1.17702448]
#  [1.1806376 ]
#  [1.18243849]
#  [1.18427289]]
# [[1.17702448]
#  [1.1806376 ]
#  [1.18243849]
#  [1.18427289]
#  [1.18700004]]
# [[1.1806376 ]
#  [1.18243849]
#  [1.18427289]
#  [1.18700004]
#  [1.18444121]]
# [[1.18243849]
#  [1.18427289]
#  [1.18700004]
#  [1.18444121]
#  [1.18034494]]
# [[1.18427289]
#  [1.18700004]
#  [1.18444121]
#  [1.18034494]
#  [1.18482006]]
# [[1.18700004]
#  [1.18444121]
#  [1.18034494]
#  [1.18482006]
#  [1.18455338]]
# [[1.18444121]
#  [1.18034494]
#  [1.18482006]
#  [1.18455338]
#  [1.17680001]]
# [[1.18034494]
#  [1.18482006]
#  [1.18455338]
#  [1.17680001]
#  [1.17083681]]
# [[1.18482006]
#  [1.18455338]
#  [1.17680001]
#  [1.17083681]
#  [1.16585445]]
# [[1.18455338]
#  [1.17680001]
#  [1.17083681]
#  [1.16585445]
#  [1.1673243 ]]
# [[1.17680001]
#  [1.17083681]
#  [1.16585445]
#  [1.1673243 ]
#  [1.16353488]]
# [[1.17083681]
#  [1.16585445]
#  [1.1673243 ]
#  [1.16353488]
#  [1.16788328]]
# [[1.16585445]
#  [1.1673243 ]
#  [1.16353488]
#  [1.16788328]
#  [1.17420506]]
# [[1.1673243 ]
#  [1.16353488]
#  [1.16788328]
#  [1.17420506]
#  [1.1726079 ]]
# [[1.16353488]
#  [1.16788328]
#  [1.17420506]
#  [1.1726079 ]
#  [1.17449462]]
# [[1.16788328]
#  [1.17420506]
#  [1.1726079 ]
#  [1.17449462]
#  [1.1720444 ]]
# [[1.17420506]
#  [1.1726079 ]
#  [1.17449462]
#  [1.1720444 ]
#  [1.17924535]]
# [[1.1726079 ]
#  [1.17449462]
#  [1.1720444 ]
#  [1.17924535]
#  [1.17376399]]
# [[1.17449462]
#  [1.1720444 ]
#  [1.17924535]
#  [1.17376399]
#  [1.17674744]]
# [[1.1720444 ]
#  [1.17924535]
#  [1.17376399]
#  [1.17674744]
#  [1.17670035]]
# [[1.17924535]
#  [1.17376399]
#  [1.17674744]
#  [1.17670035]
#  [1.1816839 ]]
# [[1.17376399]
#  [1.17674744]
#  [1.17670035]
#  [1.1816839 ]
#  [1.18161404]]
# [[1.17674744]
#  [1.17670035]
#  [1.1816839 ]
#  [1.18161404]
#  [1.17421889]]
# [[1.17670035]
#  [1.1816839 ]
#  [1.18161404]
#  [1.17421889]
#  [1.17439818]]
# [[1.1816839 ]
#  [1.18161404]
#  [1.17421889]
#  [1.17439818]
#  [1.17071342]]
# [[1.18161404]
#  [1.17421889]
#  [1.17439818]
#  [1.17071342]
#  [1.17155015]]
# [[1.17421889]
#  [1.17439818]
#  [1.17071342]
#  [1.17155015]
#  [1.17688596]]
# [[1.17439818]
#  [1.17071342]
#  [1.17155015]
#  [1.17688596]
#  [1.18298399]]
# [[1.17071342]
#  [1.17155015]
#  [1.17688596]
#  [1.18298399]
#  [1.18539596]]
# [[1.17155015]
#  [1.17688596]
#  [1.18298399]
#  [1.18539596]
#  [1.18150246]]
# [[1.17688596]
#  [1.18298399]
#  [1.18539596]
#  [1.18150246]
#  [1.18484807]]
# [[1.18298399]
#  [1.18539596]
#  [1.18150246]
#  [1.18484807]
#  [1.18094432]]
# [[1.18539596]
#  [1.18150246]
#  [1.18484807]
#  [1.18094432]
#  [1.17841148]]
# [[1.18150246]
#  [1.18484807]
#  [1.18094432]
#  [1.17841148]
#  [1.17486727]]
# [[1.18484807]
#  [1.18094432]
#  [1.17841148]
#  [1.17486727]
#  [1.16786957]]
# [[1.18094432]
#  [1.17841148]
#  [1.17486727]
#  [1.16786957]
#  [1.16421211]]
# [[1.17841148]
#  [1.17486727]
#  [1.16786957]
#  [1.16421211]
#  [1.16427994]]
# [[1.17486727]
#  [1.16786957]
#  [1.16421211]
#  [1.16427994]
#  [1.17622149]]
# [[1.16786957]
#  [1.16421211]
#  [1.16427994]
#  [1.17622149]
#  [1.1732682 ]]
# [[1.16421211]
#  [1.16427994]
#  [1.17622149]
#  [1.1732682 ]
#  [1.18175375]]
# [[1.16427994]
#  [1.17622149]
#  [1.1732682 ]
#  [1.18175375]
#  [1.18930101]]
# [[1.17622149]
#  [1.1732682 ]
#  [1.18175375]
#  [1.18930101]
#  [1.18273211]]
# [[1.1732682 ]
#  [1.18175375]
#  [1.18930101]
#  [1.18273211]
#  [1.1818794 ]]
# [[1.18175375]
#  [1.18930101]
#  [1.18273211]
#  [1.1818794 ]
#  [1.17802978]]
# [[1.18930101]
#  [1.18273211]
#  [1.1818794 ]
#  [1.17802978]
#  [1.18033934]]
# [[1.18273211]
#  [1.1818794 ]
#  [1.17802978]
#  [1.18033934]
#  [1.18452537]]
# [[1.1818794 ]
#  [1.17802978]
#  [1.18033934]
#  [1.18452537]
#  [1.1859442 ]]
# [[1.17802978]
#  [1.18033934]
#  [1.18452537]
#  [1.1859442 ]
#  [1.18636632]]
# [[1.18033934]
#  [1.18452537]
#  [1.1859442 ]
#  [1.18636632]
#  [1.18476391]]
# [[1.18452537]
#  [1.1859442 ]
#  [1.18636632]
#  [1.18476391]
#  [1.18664777]]
# [[1.1859442 ]
#  [1.18636632]
#  [1.18476391]
#  [1.18664777]
#  [1.18664777]]
# [[1.18636632]
#  [1.18476391]
#  [1.18664777]
#  [1.18664777]
#  [1.18427289]]
# [[1.18476391]
#  [1.18664777]
#  [1.18664777]
#  [1.18427289]
#  [1.1900512 ]]
# [[1.18664777]
#  [1.18664777]
#  [1.18427289]
#  [1.1900512 ]
#  [1.19200027]]
# [[1.18664777]
#  [1.18427289]
#  [1.1900512 ]
#  [1.19200027]
#  [1.19159973]]
# [[1.18427289]
#  [1.1900512 ]
#  [1.19200027]
#  [1.19159973]
#  [1.19714606]]
# [[1.1900512 ]
#  [1.19200027]
#  [1.19159973]
#  [1.19714606]
#  [1.19381607]]
# [[1.19200027]
#  [1.19159973]
#  [1.19714606]
#  [1.19381607]
#  [1.20743787]]
# [[1.19159973]
#  [1.19714606]
#  [1.19381607]
#  [1.20743787]
#  [1.21146035]]
# [[1.19714606]
#  [1.19381607]
#  [1.20743787]
#  [1.21146035]
#  [1.21456504]]
# [[1.19381607]
#  [1.20743787]
#  [1.21146035]
#  [1.21456504]
#  [1.21213591]]
# [[1.20743787]
#  [1.21146035]
#  [1.21456504]
#  [1.21213591]
#  [1.21131361]]
# [[1.21146035]
#  [1.21456504]
#  [1.21213591]
#  [1.21131361]
#  [1.21109366]]
# [[1.21456504]
#  [1.21213591]
#  [1.21131361]
#  [1.21109366]
#  [1.20787537]]
# [[1.21213591]
#  [1.21131361]
#  [1.21109366]
#  [1.20787537]
#  [1.21442938]]
# [[1.21131361]
#  [1.21109366]
#  [1.20787537]
#  [1.21442938]
#  [1.2133404 ]]
# [[1.21109366]
#  [1.20787537]
#  [1.21442938]
#  [1.2133404 ]
#  [1.21488965]]
# [[1.20787537]
#  [1.21442938]
#  [1.2133404 ]
#  [1.21488965]
#  [1.21543014]]
# [[1.21442938]
#  [1.2133404 ]
#  [1.21488965]
#  [1.21543014]
#  [1.21995854]]
# [[1.2133404 ]
#  [1.21488965]
#  [1.21543014]
#  [1.21995854]
#  [1.22627163]]
# [[1.21488965]
#  [1.21543014]
#  [1.21995854]
#  [1.22627163]
#  [1.22161281]]
# [[1.21543014]
#  [1.21995854]
#  [1.22627163]
#  [1.22161281]
#  [1.22369063]]
# [[1.21995854]
#  [1.22627163]
#  [1.22161281]
#  [1.22369063]
#  [1.21866512]]
# [[1.22627163]
#  [1.22161281]
#  [1.22369063]
#  [1.21866512]
#  [1.21914053]]
# [[1.22161281]
#  [1.22369063]
#  [1.21866512]
#  [1.21914053]
#  [1.218472  ]]
# [[1.22369063]
#  [1.21866512]
#  [1.21914053]
#  [1.218472  ]
#  [1.22050953]]
# [[1.21866512]
#  [1.21914053]
#  [1.218472  ]
#  [1.22050953]
#  [1.22234452]]
# [[1.21914053]
#  [1.218472  ]
#  [1.22050953]
#  [1.22234452]
#  [1.22529507]]
# [[1.218472  ]
#  [1.22050953]
#  [1.22234452]
#  [1.22529507]
#  [1.22998965]]
# [[1.22050953]
#  [1.22234452]
#  [1.22529507]
#  [1.22998965]
#  [1.21802688]]
# [[1.22234452]
#  [1.22529507]
#  [1.22998965]
#  [1.21802688]
#  [1.22506976]]
# [[1.22529507]
#  [1.22998965]
#  [1.21802688]
#  [1.22506976]
#  [1.22515988]]
# [[1.22998965]
#  [1.21802688]
#  [1.22506976]
#  [1.22515988]
#  [1.23002744]]
# [[1.21802688]
#  [1.22506976]
#  [1.22515988]
#  [1.23002744]
#  [1.23411083]]
# [[1.22506976]
#  [1.22515988]
#  [1.23002744]
#  [1.23411083]
#  [1.22714448]]
# [[1.22515988]
#  [1.23002744]
#  [1.23411083]
#  [1.22714448]
#  [1.21862054]]
# [[1.23002744]
#  [1.23411083]
#  [1.22714448]
#  [1.21862054]
#  [1.21607018]]
# [[1.23411083]
#  [1.22714448]
#  [1.21862054]
#  [1.21607018]
#  [1.22088945]]
# [[1.22714448]
#  [1.21862054]
#  [1.21607018]
#  [1.22088945]
#  [1.21624911]]
# [[1.21862054]
#  [1.21607018]
#  [1.22088945]
#  [1.21624911]
#  [1.21512592]]
# [[1.21607018]
#  [1.22088945]
#  [1.21624911]
#  [1.21512592]
#  [1.20681131]]
# [[1.22088945]
#  [1.21624911]
#  [1.21512592]
#  [1.20681131]
#  [1.20772946]]
# [[1.21624911]
#  [1.21512592]
#  [1.20681131]
#  [1.20772946]
#  [1.21388686]]
# [[1.21512592]
#  [1.20681131]
#  [1.20772946]
#  [1.21388686]
#  [1.21156311]]
# [[1.20681131]
#  [1.20772946]
#  [1.21388686]
#  [1.21156311]
#  [1.21662939]]
# [[1.20772946]
#  [1.21388686]
#  [1.21156311]
#  [1.21662939]
#  [1.21694469]]
# [[1.21388686]
#  [1.21156311]
#  [1.21662939]
#  [1.21694469]
#  [1.21462405]]
# [[1.21156311]
#  [1.21662939]
#  [1.21694469]
#  [1.21462405]
#  [1.2162993 ]]
# [[1.21662939]
#  [1.21694469]
#  [1.21462405]
#  [1.2162993 ]
#  [1.21050727]]
# [[1.21694469]
#  [1.21462405]
#  [1.2162993 ]
#  [1.21050727]
#  [1.21200371]]
# [[1.21462405]
#  [1.2162993 ]
#  [1.21050727]
#  [1.21200371]
#  [1.21238577]]
# [[1.2162993 ]
#  [1.21050727]
#  [1.21200371]
#  [1.21238577]
#  [1.20686948]]
# [[1.21050727]
#  [1.21200371]
#  [1.21238577]
#  [1.20686948]
#  [1.20390546]]
# [[1.21200371]
#  [1.21238577]
#  [1.20686948]
#  [1.20390546]
#  [1.20423889]]
# [[1.21238577]
#  [1.20686948]
#  [1.20390546]
#  [1.20423889]
#  [1.19667315]]
# [[1.20686948]
#  [1.20390546]
#  [1.20423889]
#  [1.19667315]
#  [1.20487738]]
# [[1.20390546]
#  [1.20423889]
#  [1.19667315]
#  [1.20487738]
#  [1.20535958]]
# [[1.20423889]
#  [1.19667315]
#  [1.20487738]
#  [1.20535958]
#  [1.2119993 ]]
# [[1.19667315]
#  [1.20487738]
#  [1.20535958]
#  [1.2119993 ]
#  [1.21212125]]
# [[1.20487738]
#  [1.20535958]
#  [1.2119993 ]
#  [1.21212125]
#  [1.21315062]]
# [[1.20535958]
#  [1.2119993 ]
#  [1.21212125]
#  [1.21315062]
#  [1.21220934]]
# [[1.2119993 ]
#  [1.21212125]
#  [1.21315062]
#  [1.21220934]
#  [1.21321964]]
# [[1.21212125]
#  [1.21315062]
#  [1.21220934]
#  [1.21321964]
#  [1.2092483 ]]
# [[1.21315062]
#  [1.21220934]
#  [1.21321964]
#  [1.2092483 ]
#  [1.20480049]]
# [[1.21220934]
#  [1.21321964]
#  [1.2092483 ]
#  [1.20480049]
#  [1.20918977]]
# [[1.21321964]
#  [1.2092483 ]
#  [1.20480049]
#  [1.20918977]
#  [1.21263564]]
# [[1.2092483 ]
#  [1.20480049]
#  [1.20918977]
#  [1.21263564]
#  [1.21667969]]
# [[1.20480049]
#  [1.20918977]
#  [1.21263564]
#  [1.21667969]
#  [1.21521449]]
# [[1.20918977]
#  [1.21263564]
#  [1.21667969]
#  [1.21521449]
#  [1.21713722]]
# [[1.21263564]
#  [1.21667969]
#  [1.21521449]
#  [1.21713722]
#  [1.21604204]]
# [[1.21667969]
#  [1.21521449]
#  [1.21713722]
#  [1.21604204]
#  [1.208956  ]]
# [[1.21521449]
#  [1.21713722]
#  [1.21604204]
#  [1.208956  ]
#  [1.2051096 ]]
# [[1.21713722]
#  [1.21604204]
#  [1.208956  ]
#  [1.2051096 ]
#  [1.20854676]]
# [[1.21604204]
#  [1.208956  ]
#  [1.2051096 ]
#  [1.20854676]
#  [1.20506608]]
# [[1.208956  ]
#  [1.2051096 ]
#  [1.20854676]
#  [1.20506608]
#  [1.19677353]]
# [[1.2051096 ]
#  [1.20854676]
#  [1.20506608]
#  [1.19677353]
#  [1.19256318]]
# [[1.20854676]
#  [1.20506608]
#  [1.19677353]
#  [1.19256318]
#  [1.18517113]]
# [[1.20506608]
#  [1.19677353]
#  [1.19256318]
#  [1.18517113]
#  [1.18979061]]
# [[1.19677353]
#  [1.19256318]
#  [1.18517113]
#  [1.18979061]
#  [1.19260585]]
# [[1.19256318]
#  [1.18517113]
#  [1.18979061]
#  [1.19260585]
#  [1.19860959]]
# [[1.18517113]
#  [1.18979061]
#  [1.19260585]
#  [1.19860959]
#  [1.19500005]]
# [[1.18979061]
#  [1.19260585]
#  [1.19860959]
#  [1.19500005]
#  [1.19257736]]
# [[1.19260585]
#  [1.19860959]
#  [1.19500005]
#  [1.19257736]
#  [1.19016457]]
# [[1.19860959]
#  [1.19500005]
#  [1.19257736]
#  [1.19016457]
#  [1.19827926]]
# [[1.19500005]
#  [1.19257736]
#  [1.19016457]
#  [1.19827926]
#  [1.19182408]]
# [[1.19257736]
#  [1.19016457]
#  [1.19827926]
#  [1.19182408]
#  [1.1883117 ]]
# [[1.19016457]
#  [1.19827926]
#  [1.19182408]
#  [1.1883117 ]
#  [1.19330311]]
# [[1.19827926]
#  [1.19182408]
#  [1.1883117 ]
#  [1.19330311]
#  [1.18402052]]
# [[1.19182408]
#  [1.1883117 ]
#  [1.19330311]
#  [1.18402052]
#  [1.18130696]]
# [[1.1883117 ]
#  [1.19330311]
#  [1.18402052]
#  [1.18130696]
#  [1.17766213]]
# [[1.19330311]
#  [1.18402052]
#  [1.18130696]
#  [1.17766213]
#  [1.17880046]]
# [[1.18402052]
#  [1.18130696]
#  [1.17766213]
#  [1.17880046]
#  [1.17710066]]
# [[1.18130696]
#  [1.17766213]
#  [1.17880046]
#  [1.17710066]
#  [1.17236042]]
# [[1.17766213]
#  [1.17880046]
#  [1.17710066]
#  [1.17236042]
#  [1.17288303]]
# [[1.17880046]
#  [1.17710066]
#  [1.17236042]
#  [1.17288303]
#  [1.17799497]]
# [[1.17710066]
#  [1.17236042]
#  [1.17288303]
#  [1.17799497]
#  [1.1768167 ]]
# [[1.17236042]
#  [1.17288303]
#  [1.17799497]
#  [1.1768167 ]
#  [1.18189347]]
# [[1.17288303]
#  [1.17799497]
#  [1.1768167 ]
#  [1.18189347]
#  [1.18742287]]
# [[1.17799497]
#  [1.1768167 ]
#  [1.18189347]
#  [1.18742287]
#  [1.18736649]]
# [[1.1768167 ]
#  [1.18189347]
#  [1.18742287]
#  [1.18736649]
#  [1.19156849]]
# [[1.18189347]
#  [1.18742287]
#  [1.18736649]
#  [1.19156849]
#  [1.1900512 ]]
# [[1.18742287]
#  [1.18736649]
#  [1.19156849]
#  [1.1900512 ]
#  [1.19146907]]
# [[1.18736649]
#  [1.19156849]
#  [1.1900512 ]
#  [1.19146907]
#  [1.1954143 ]]
# [[1.19156849]
#  [1.1900512 ]
#  [1.19146907]
#  [1.1954143 ]
#  [1.19860959]]
# [[1.1900512 ]
#  [1.19146907]
#  [1.1954143 ]
#  [1.19860959]
#  [1.19717467]]
# [[1.19146907]
#  [1.1954143 ]
#  [1.19860959]
#  [1.19717467]
#  [1.19694543]]
# [[1.1954143 ]
#  [1.19860959]
#  [1.19717467]
#  [1.19694543]
#  [1.20452905]]
# [[1.19860959]
#  [1.19717467]
#  [1.19694543]
#  [1.20452905]
#  [1.2032392 ]]
# [[1.19717467]
#  [1.19694543]
#  [1.20452905]
#  [1.2032392 ]
#  [1.20377505]]
# [[1.19694543]
#  [1.20452905]
#  [1.2032392 ]
#  [1.20377505]
#  [1.20147538]]
# [[1.20452905]
#  [1.2032392 ]
#  [1.20377505]
#  [1.20147538]
#  [1.20898521]]
# [[1.2032392 ]
#  [1.20377505]
#  [1.20147538]
#  [1.20898521]
#  [1.2081672 ]]
# [[1.20377505]
#  [1.20147538]
#  [1.20898521]
#  [1.2081672 ]
#  [1.20903051]]
# [[1.20147538]
#  [1.20898521]
#  [1.2081672 ]
#  [1.20903051]
#  [1.21359229]]
# [[1.20898521]
#  [1.2081672 ]
#  [1.20903051]
#  [1.21359229]
#  [1.21270919]]
# [[1.2081672 ]
#  [1.20903051]
#  [1.21359229]
#  [1.21270919]
#  [1.20277607]]
# [[1.20903051]
#  [1.21359229]
#  [1.21270919]
#  [1.20277607]
#  [1.20612717]]
# [[1.21359229]
#  [1.21270919]
#  [1.20277607]
#  [1.20612717]
#  [1.20150435]]
# [[1.21270919]
#  [1.20277607]
#  [1.20612717]
#  [1.20150435]
#  [1.20079732]]
# [[1.20277607]
#  [1.20612717]
#  [1.20150435]
#  [1.20079732]
#  [1.20685494]]
# [[1.20612717]
#  [1.20150435]
#  [1.20079732]
#  [1.20685494]
#  [1.21710765]]
# [[1.20150435]
#  [1.20079732]
#  [1.20685494]
#  [1.21710765]
#  [1.21409321]]
# [[1.20079732]
#  [1.20685494]
#  [1.21710765]
#  [1.21409321]
#  [1.21445   ]]
# [[1.20685494]
#  [1.21710765]
#  [1.21409321]
#  [1.21445   ]
#  [1.20785058]]
# [[1.21710765]
#  [1.21409321]
#  [1.21445   ]
#  [1.20785058]
#  [1.20772946]]
# [[1.21409321]
#  [1.21445   ]
#  [1.20785058]
#  [1.20772946]
#  [1.21503735]]
# [[1.21445   ]
#  [1.20785058]
#  [1.20772946]
#  [1.21503735]
#  [1.21568727]]
# [[1.20785058]
#  [1.20772946]
#  [1.21503735]
#  [1.21568727]
#  [1.22239971]]
# [[1.20772946]
#  [1.21503735]
#  [1.21568727]
#  [1.22239971]
#  [1.21728539]]
# [[1.21503735]
#  [1.21568727]
#  [1.22239971]
#  [1.21728539]
#  [1.22253871]]
# [[1.21568727]
#  [1.22239971]
#  [1.21728539]
#  [1.22253871]
#  [1.21832359]]
# [[1.22239971]
#  [1.21728539]
#  [1.22253871]
#  [1.21832359]
#  [1.22146356]]
# [[1.21728539]
#  [1.22253871]
#  [1.21832359]
#  [1.22146356]
#  [1.22490931]]
# [[1.22253871]
#  [1.21832359]
#  [1.22146356]
#  [1.22490931]
#  [1.2192595 ]]
# [[1.21832359]
#  [1.22146356]
#  [1.22490931]
#  [1.2192595 ]
#  [1.21931887]]
# [[1.22146356]
#  [1.22490931]
#  [1.2192595 ]
#  [1.21931887]
#  [1.21900678]]
# [[1.22490931]
#  [1.2192595 ]
#  [1.21931887]
#  [1.21900678]
#  [1.22328651]]
# [[1.2192595 ]
#  [1.21931887]
#  [1.21900678]
#  [1.22328651]
#  [1.22177696]]
# [[1.21931887]
#  [1.21900678]
#  [1.22328651]
#  [1.22177696]
#  [1.22098625]]
# [[1.21900678]
#  [1.22328651]
#  [1.22177696]
#  [1.22098625]
#  [1.2133007 ]]
# [[1.22328651]
#  [1.22177696]
#  [1.22098625]
#  [1.2133007 ]
#  [1.2168411 ]]
# [[1.22177696]
#  [1.22098625]
#  [1.2133007 ]
#  [1.2168411 ]
#  [1.21936345]]
# [[1.22098625]
#  [1.2133007 ]
#  [1.2168411 ]
#  [1.21936345]
#  [1.21728539]]
# [[1.2133007 ]
#  [1.2168411 ]
#  [1.21936345]
#  [1.21728539]
#  [1.21820045]]
# [[1.2168411 ]
#  [1.21936345]
#  [1.21728539]
#  [1.21820045]
#  [1.21725583]]
# [[1.21936345]
#  [1.21728539]
#  [1.21820045]
#  [1.21725583]
#  [1.21102035]]
# [[1.21728539]
#  [1.21820045]
#  [1.21725583]
#  [1.21102035]
#  [1.21222401]]
# [[1.21820045]
#  [1.21725583]
#  [1.21102035]
#  [1.21222401]
#  [1.21270919]]
# [[1.21725583]
#  [1.21102035]
#  [1.21222401]
#  [1.21270919]
#  [1.19955862]]
# [[1.21102035]
#  [1.21222401]
#  [1.21270919]
#  [1.19955862]
#  [1.1913414 ]]
# [[1.21222401]
#  [1.21270919]
#  [1.19955862]
#  [1.1913414 ]
#  [1.18736649]]
# [[1.21270919]
#  [1.19955862]
#  [1.1913414 ]
#  [1.18736649]
#  [1.19125617]]
# [[1.19955862]
#  [1.1913414 ]
#  [1.18736649]
#  [1.19125617]
#  [1.19367349]]
# [[1.1913414 ]
#  [1.18736649]
#  [1.19125617]
#  [1.19367349]
#  [1.19331741]]
# [[1.18736649]
#  [1.19125617]
#  [1.19367349]
#  [1.19331741]
#  [1.19303274]]
# [[1.19125617]
#  [1.19367349]
#  [1.19331741]
#  [1.19303274]
#  [1.1942153 ]]
# [[1.19367349]
#  [1.19331741]
#  [1.19303274]
#  [1.1942153 ]
#  [1.19289041]]
# [[1.19331741]
#  [1.19303274]
#  [1.1942153 ]
#  [1.19289041]
#  [1.19019282]]
# [[1.19303274]
#  [1.1942153 ]
#  [1.19289041]
#  [1.19019282]
#  [1.18567705]]
# [[1.1942153 ]
#  [1.19289041]
#  [1.19019282]
#  [1.18567705]
#  [1.1846236 ]]
# [[1.19289041]
#  [1.19019282]
#  [1.18567705]
#  [1.1846236 ]
#  [1.18562078]]
# [[1.19019282]
#  [1.18567705]
#  [1.1846236 ]
#  [1.18562078]
#  [1.18638039]]
# [[1.18567705]
#  [1.1846236 ]
#  [1.18562078]
#  [1.18638039]
#  [1.18245232]]
# [[1.1846236 ]
#  [1.18562078]
#  [1.18638039]
#  [1.18245232]
#  [1.17933989]]
# [[1.18562078]
#  [1.18638039]
#  [1.18245232]
#  [1.17933989]
#  [1.18480039]]
# [[1.18638039]
#  [1.18245232]
#  [1.17933989]
#  [1.18480039]
#  [1.18729591]]
# [[1.18245232]
#  [1.17933989]
#  [1.18480039]
#  [1.18729591]
#  [1.18652105]]
# [[1.17933989]
#  [1.18480039]
#  [1.18729591]
#  [1.18652105]
#  [1.17753732]]
# [[1.18480039]
#  [1.18729591]
#  [1.18652105]
#  [1.17753732]
#  [1.18333387]]
# [[1.18729591]
#  [1.18652105]
#  [1.17753732]
#  [1.18333387]
#  [1.18118143]]
# [[1.18652105]
#  [1.17753732]
#  [1.18333387]
#  [1.18118143]
#  [1.18140054]]
# [[1.17753732]
#  [1.18333387]
#  [1.18118143]
#  [1.18140054]
#  [1.17938435]]
# [[1.18333387]
#  [1.18118143]
#  [1.18140054]
#  [1.17938435]
#  [1.17841148]]
# [[1.18118143]
#  [1.18140054]
#  [1.17938435]
#  [1.17841148]
#  [1.17927301]]
# [[1.18140054]
#  [1.17938435]
#  [1.17841148]
#  [1.17927301]
#  [1.17727387]]
# [[1.17938435]
#  [1.17841148]
#  [1.17927301]
#  [1.17727387]
#  [1.17734325]]
# [[1.17841148]
#  [1.17927301]
#  [1.17727387]
#  [1.17734325]
#  [1.18077695]]
# [[1.17927301]
#  [1.17727387]
#  [1.17734325]
#  [1.18077695]
#  [1.18231261]]
# [[1.17727387]
#  [1.17734325]
#  [1.18077695]
#  [1.18231261]
#  [1.18459558]]
# [[1.17734325]
#  [1.18077695]
#  [1.18231261]
#  [1.18459558]
#  [1.1892997 ]]
# [[1.18077695]
#  [1.18231261]
#  [1.18459558]
#  [1.1892997 ]
#  [1.18670416]]
# [[1.18231261]
#  [1.18459558]
#  [1.1892997 ]
#  [1.18670416]
#  [1.18746507]]
# [[1.18459558]
#  [1.1892997 ]
#  [1.18670416]
#  [1.18746507]
#  [1.18694365]]
# [[1.1892997 ]
#  [1.18670416]
#  [1.18746507]
#  [1.18694365]
#  [1.18374014]]
# [[1.18670416]
#  [1.18746507]
#  [1.18694365]
#  [1.18374014]
#  [1.18357205]]
# [[1.18746507]
#  [1.18694365]
#  [1.18374014]
#  [1.18357205]
#  [1.17495   ]]
# [[1.18694365]
#  [1.18374014]
#  [1.18357205]
#  [1.17495   ]
#  [1.17384672]]
# [[1.18374014]
#  [1.18357205]
#  [1.17495   ]
#  [1.17384672]
#  [1.172333  ]]
# [[1.18357205]
#  [1.17495   ]
#  [1.17384672]
#  [1.172333  ]
#  [1.17418993]]
# [[1.17495   ]
#  [1.17384672]
#  [1.172333  ]
#  [1.17418993]
#  [1.17362618]]
# [[1.17384672]
#  [1.172333  ]
#  [1.17418993]
#  [1.17362618]
#  [1.1794678 ]]
# [[1.172333  ]
#  [1.17418993]
#  [1.17362618]
#  [1.1794678 ]
#  [1.17799497]]
# [[1.17418993]
#  [1.17362618]
#  [1.1794678 ]
#  [1.17799497]
#  [1.1709739 ]]
# [[1.17362618]
#  [1.1794678 ]
#  [1.17799497]
#  [1.1709739 ]
#  [1.17032981]]
# [[1.1794678 ]
#  [1.17799497]
#  [1.1709739 ]
#  [1.17032981]
#  [1.16765952]]
# [[1.17799497]
#  [1.1709739 ]
#  [1.17032981]
#  [1.16765952]
#  [1.16975486]]
# [[1.1709739 ]
#  [1.17032981]
#  [1.16765952]
#  [1.16975486]
#  [1.17445338]]
# [[1.17032981]
#  [1.16765952]
#  [1.16975486]
#  [1.17445338]
#  [1.17530918]]
# [[1.16765952]
#  [1.16975486]
#  [1.17445338]
#  [1.17530918]
#  [1.17744017]]
# [[1.16975486]
#  [1.17445338]
#  [1.17530918]
#  [1.17744017]
#  [1.1756407 ]]
# [[1.17445338]
#  [1.17530918]
#  [1.17744017]
#  [1.1756407 ]
#  [1.17990065]]
# [[1.17530918]
#  [1.17744017]
#  [1.1756407 ]
#  [1.17990065]
#  [1.17969048]]
# [[1.17744017]
#  [1.1756407 ]
#  [1.17990065]
#  [1.17969048]
#  [1.18102801]]
# [[1.1756407 ]
#  [1.17990065]
#  [1.17969048]
#  [1.18102801]
#  [1.18409061]]
# [[1.17990065]
#  [1.17969048]
#  [1.18102801]
#  [1.18409061]
#  [1.18764842]]
# [[1.17969048]
#  [1.18102801]
#  [1.18409061]
#  [1.18764842]
#  [1.18859422]]
# [[1.18102801]
#  [1.18409061]
#  [1.18764842]
#  [1.18859422]
#  [1.18750739]]
# [[1.18409061]
#  [1.18764842]
#  [1.18859422]
#  [1.18750739]
#  [1.18435693]]
# [[1.18764842]
#  [1.18859422]
#  [1.18750739]
#  [1.18435693]
#  [1.18191016]]
# [[1.18859422]
#  [1.18750739]
#  [1.18435693]
#  [1.18191016]
#  [1.18259227]]
# [[1.18750739]
#  [1.18435693]
#  [1.18191016]
#  [1.18259227]
#  [1.18119538]]
# [[1.18435693]
#  [1.18191016]
#  [1.18259227]
#  [1.18119538]
#  [1.18119538]]
# [[1.18191016]
#  [1.18259227]
#  [1.18119538]
#  [1.18119538]
#  [1.18049812]]
# [[1.18259227]
#  [1.18119538]
#  [1.18119538]
#  [1.18049812]
#  [1.18199956]]
# [[1.18119538]
#  [1.18119538]
#  [1.18049812]
#  [1.18199956]
#  [1.17674744]]
# [[1.18119538]
#  [1.18049812]
#  [1.18199956]
#  [1.17674744]
#  [1.17299306]]
# [[1.18049812]
#  [1.18199956]
#  [1.17674744]
#  [1.17299306]
#  [1.17302048]]
# [[1.18199956]
#  [1.17674744]
#  [1.17299306]
#  [1.17302048]
#  [1.17229164]]
# [[1.17674744]
#  [1.17299306]
#  [1.17302048]
#  [1.17229164]
#  [1.16877043]]
# [[1.17299306]
#  [1.17302048]
#  [1.17229164]
#  [1.16877043]
#  [1.17402589]]
# [[1.17302048]
#  [1.17229164]
#  [1.16877043]
#  [1.17402589]
#  [1.17230546]]
# [[1.17229164]
#  [1.16877043]
#  [1.17402589]
#  [1.17230546]
#  [1.16967952]]
# [[1.16877043]
#  [1.17402589]
#  [1.17230546]
#  [1.16967952]
#  [1.16863382]]
# [[1.17402589]
#  [1.17230546]
#  [1.16967952]
#  [1.16863382]
#  [1.16016018]]
# [[1.17230546]
#  [1.16967952]
#  [1.16863382]
#  [1.16016018]
#  [1.15744758]]
# [[1.16967952]
#  [1.16863382]
#  [1.16016018]
#  [1.15744758]
#  [1.16072571]]
# [[1.16863382]
#  [1.16016018]
#  [1.15744758]
#  [1.16072571]
#  [1.16184497]]
# [[1.16016018]
#  [1.15744758]
#  [1.16072571]
#  [1.16184497]
#  [1.15960848]]
# [[1.15744758]
#  [1.16072571]
#  [1.16184497]
#  [1.15960848]
#  [1.15553498]]
# [[1.16072571]
#  [1.16184497]
#  [1.15960848]
#  [1.15553498]
#  [1.15597582]]
# [[1.16184497]
#  [1.15960848]
#  [1.15553498]
#  [1.15597582]
#  [1.15660417]]
# [[1.15960848]
#  [1.15553498]
#  [1.15597582]
#  [1.15660417]
#  [1.15537477]]
# [[1.15553498]
#  [1.15597582]
#  [1.15660417]
#  [1.15537477]
#  [1.15340257]]
# [[1.15597582]
#  [1.15660417]
#  [1.15537477]
#  [1.15340257]
#  [1.15995824]]
# [[1.15660417]
#  [1.15537477]
#  [1.15340257]
#  [1.15995824]
#  [1.15915155]]
# [[1.15537477]
#  [1.15340257]
#  [1.15995824]
#  [1.15915155]
#  [1.15970266]]
# [[1.15340257]
#  [1.15995824]
#  [1.15915155]
#  [1.15970266]
#  [1.16138625]]
# [[1.15995824]
#  [1.15915155]
#  [1.15970266]
#  [1.16138625]
#  [1.16319644]]
# [[1.15915155]
#  [1.15970266]
#  [1.16138625]
#  [1.16319644]
#  [1.16550124]]
# [[1.15970266]
#  [1.16138625]
#  [1.16319644]
#  [1.16550124]
#  [1.16253388]]
# [[1.16138625]
#  [1.16319644]
#  [1.16550124]
#  [1.16253388]
#  [1.16400886]]
# [[1.16319644]
#  [1.16550124]
#  [1.16253388]
#  [1.16400886]
#  [1.16117048]]
# [[1.16550124]
#  [1.16253388]
#  [1.16400886]
#  [1.16117048]
#  [1.15982366]]
# [[1.16253388]
#  [1.16400886]
#  [1.16117048]
#  [1.15982366]
#  [1.16001201]]
# [[1.16400886]
#  [1.16117048]
#  [1.15982366]
#  [1.16001201]
#  [1.16836083]]
# [[1.16117048]
#  [1.15982366]
#  [1.16001201]
#  [1.16836083]
#  [1.1556685 ]]
# [[1.15982366]
#  [1.16001201]
#  [1.16836083]
#  [1.1556685 ]
#  [1.15995824]]
# [[1.16001201]
#  [1.16836083]
#  [1.1556685 ]
#  [1.15995824]
#  [1.15794349]]
# [[1.16836083]
#  [1.1556685 ]
#  [1.15995824]
#  [1.15794349]
#  [1.16157508]]
# [[1.1556685 ]
#  [1.15995824]
#  [1.15794349]
#  [1.16157508]
#  [1.15553498]]
# [[1.15995824]
#  [1.15794349]
#  [1.16157508]
#  [1.15553498]
#  [1.15688515]]
# [[1.15794349]
#  [1.16157508]
#  [1.15553498]
#  [1.15688515]
#  [1.15915155]]
# [[1.16157508]
#  [1.15553498]
#  [1.15688515]
#  [1.15915155]
#  [1.15955472]]
# [[1.15553498]
#  [1.15688515]
#  [1.15915155]
#  [1.15955472]
#  [1.14859354]]
# [[1.15688515]
#  [1.15915155]
#  [1.15955472]
#  [1.14859354]
#  [1.14508188]]
# [[1.15915155]
#  [1.15955472]
#  [1.14859354]
#  [1.14508188]
#  [1.1441648 ]]
# [[1.15955472]
#  [1.14859354]
#  [1.14508188]
#  [1.1441648 ]
#  [1.13664782]]
# [[1.14859354]
#  [1.14508188]
#  [1.1441648 ]
#  [1.13664782]
#  [1.13211823]]
# [[1.14508188]
#  [1.1441648 ]
#  [1.13664782]
#  [1.13211823]
#  [1.13211823]]
# [[1.1441648 ]
#  [1.13664782]
#  [1.13211823]
#  [1.13211823]
#  [1.13684154]]
# [[1.13664782]
#  [1.13211823]
#  [1.13211823]
#  [1.13684154]
#  [1.12757373]]
# [[1.13211823]
#  [1.13211823]
#  [1.13684154]
#  [1.12757373]
#  [1.12421453]]
# [[1.13211823]
#  [1.13684154]
#  [1.12757373]
#  [1.12421453]
#  [1.12449265]]
# [[1.13684154]
#  [1.12757373]
#  [1.12421453]
#  [1.12449265]
#  [1.12029755]]
# [[1.12757373]
#  [1.12421453]
#  [1.12449265]
#  [1.12029755]
#  [1.1209631 ]]
# [[1.12421453]
#  [1.12449265]
#  [1.12029755]
#  [1.1209631 ]
#  [1.12931824]]
# [[1.12449265]
#  [1.12029755]
#  [1.1209631 ]
#  [1.12931824]
#  [1.12934375]]
# [[1.12029755]
#  [1.1209631 ]
#  [1.12931824]
#  [1.12934375]
#  [1.13302898]]
# [[1.1209631 ]
#  [1.12931824]
#  [1.12934375]
#  [1.13302898]
#  [1.13195157]]
# [[1.12931824]
#  [1.12934375]
#  [1.13302898]
#  [1.13195157]
#  [1.1306206 ]]
# [[1.12934375]
#  [1.13302898]
#  [1.13195157]
#  [1.1306206 ]
#  [1.13047993]]
# [[1.13302898]
#  [1.13195157]
#  [1.1306206 ]
#  [1.13047993]
#  [1.12866819]]
# [[1.13195157]
#  [1.1306206 ]
#  [1.13047993]
#  [1.12866819]
#  [1.12765002]]
# [[1.1306206 ]
#  [1.13047993]
#  [1.12866819]
#  [1.12765002]
#  [1.13455868]]
# [[1.13047993]
#  [1.12866819]
#  [1.12765002]
#  [1.13455868]
#  [1.12933099]]
# [[1.12866819]
#  [1.12765002]
#  [1.13455868]
#  [1.12933099]
#  [1.13118339]]
# [[1.12765002]
#  [1.13455868]
#  [1.12933099]
#  [1.13118339]
#  [1.12854075]]
# [[1.13455868]
#  [1.12933099]
#  [1.13118339]
#  [1.12854075]
#  [1.12612617]]
# [[1.12933099]
#  [1.13118339]
#  [1.12854075]
#  [1.12612617]
#  [1.12907588]]
# [[1.13118339]
#  [1.12854075]
#  [1.12612617]
#  [1.12907588]
#  [1.13341415]]
# [[1.12854075]
#  [1.12612617]
#  [1.12907588]
#  [1.13341415]
#  [1.12435353]]
# [[1.12612617]
#  [1.12907588]
#  [1.13341415]
#  [1.12435353]
#  [1.12775171]]
# [[1.12907588]
#  [1.13341415]
#  [1.12435353]
#  [1.12775171]
#  [1.12875736]]
# [[1.13341415]
#  [1.12435353]
#  [1.12775171]
#  [1.12875736]
#  [1.13288772]]
# [[1.12435353]
#  [1.12775171]
#  [1.12875736]
#  [1.13288772]
#  [1.1327337 ]]
# [[1.12775171]
#  [1.12875736]
#  [1.13288772]
#  [1.1327337 ]
#  [1.1324259 ]]
# [[1.12875736]
#  [1.13288772]
#  [1.1327337 ]
#  [1.1324259 ]
#  [1.13300323]]
# [[1.13288772]
#  [1.1327337 ]
#  [1.1324259 ]
#  [1.13300323]
#  [1.13147771]]
# [[1.1327337 ]
#  [1.1324259 ]
#  [1.13300323]
#  [1.13147771]
#  [1.13601506]]
# [[1.1324259 ]
#  [1.13300323]
#  [1.13147771]
#  [1.13601506]
#  [1.13250279]]
# [[1.13300323]
#  [1.13147771]
#  [1.13601506]
#  [1.13250279]
#  [1.13734591]]
# [[1.13147771]
#  [1.13601506]
#  [1.13250279]
#  [1.13734591]
#  [1.13022447]]
# [[1.13601506]
#  [1.13250279]
#  [1.13734591]
#  [1.13022447]
#  [1.12836254]]
# [[1.13250279]
#  [1.13734591]
#  [1.13022447]
#  [1.12836254]
#  [1.13134968]]
# [[1.13734591]
#  [1.13022447]
#  [1.12836254]
#  [1.13134968]
#  [1.12968814]]
# [[1.13022447]
#  [1.12836254]
#  [1.13134968]
#  [1.12968814]
#  [1.135396  ]]
# [[1.12836254]
#  [1.13134968]
#  [1.12968814]
#  [1.135396  ]
#  [1.13304174]]
# [[1.13134968]
#  [1.12968814]
#  [1.135396  ]
#  [1.13304174]
#  [1.13664782]]
# [[1.12968814]
#  [1.135396  ]
#  [1.13304174]
#  [1.13664782]
#  [1.1441648 ]]
# [[1.135396  ]
#  [1.13304174]
#  [1.13664782]
#  [1.1441648 ]
#  [1.14571154]]
# [[1.13304174]
#  [1.13664782]
#  [1.1441648 ]
#  [1.14571154]
#  [1.14107049]]
# [[1.13664782]
#  [1.1441648 ]
#  [1.14571154]
#  [1.14107049]
#  [1.14105749]]
# [[1.1441648 ]
#  [1.14571154]
#  [1.14107049]
#  [1.14105749]
#  [1.13296473]]
# [[1.14571154]
#  [1.14107049]
#  [1.14105749]
#  [1.13296473]
#  [1.13433993]]
# [[1.14107049]
#  [1.14105749]
#  [1.13296473]
#  [1.13433993]
#  [1.13137531]]
# [[1.14105749]
#  [1.13296473]
#  [1.13433993]
#  [1.13137531]
#  [1.13414693]]
# [[1.13296473]
#  [1.13433993]
#  [1.13137531]
#  [1.13414693]
#  [1.13241303]]
# [[1.13433993]
#  [1.13137531]
#  [1.13414693]
#  [1.13241303]
#  [1.13045442]]
# [[1.13137531]
#  [1.13414693]
#  [1.13241303]
#  [1.13045442]
#  [1.12435353]]
# [[1.13414693]
#  [1.13241303]
#  [1.13045442]
#  [1.12435353]
#  [1.11470294]]
# [[1.13241303]
#  [1.13045442]
#  [1.12435353]
#  [1.11470294]
#  [1.11523747]]
# [[1.13045442]
#  [1.12435353]
#  [1.11470294]
#  [1.11523747]
#  [1.12296462]]
# [[1.12435353]
#  [1.11470294]
#  [1.11523747]
#  [1.12296462]
#  [1.12739563]]
# [[1.11470294]
#  [1.11523747]
#  [1.12296462]
#  [1.12739563]
#  [1.12999463]]
# [[1.11523747]
#  [1.12296462]
#  [1.12739563]
#  [1.12999463]
#  [1.14357591]]
# [[1.12296462]
#  [1.12739563]
#  [1.12999463]
#  [1.14357591]
#  [1.14551473]]
# [[1.12739563]
#  [1.12999463]
#  [1.14357591]
#  [1.14551473]
#  [1.14429569]]
# [[1.12999463]
#  [1.14357591]
#  [1.14551473]
#  [1.14429569]
#  [1.1421262 ]]
# [[1.14357591]
#  [1.14551473]
#  [1.14429569]
#  [1.1421262 ]
#  [1.14215219]]
# [[1.14551473]
#  [1.14429569]
#  [1.1421262 ]
#  [1.14215219]
#  [1.14155257]]
# [[1.14429569]
#  [1.1421262 ]
#  [1.14215219]
#  [1.14155257]
#  [1.13650572]]
# [[1.1421262 ]
#  [1.14215219]
#  [1.14155257]
#  [1.13650572]
#  [1.13063347]]
# [[1.14215219]
#  [1.14155257]
#  [1.13650572]
#  [1.13063347]
#  [1.1356796 ]]
# [[1.14155257]
#  [1.13650572]
#  [1.13063347]
#  [1.1356796 ]
#  [1.13752699]]
# [[1.13650572]
#  [1.13063347]
#  [1.1356796 ]
#  [1.13752699]
#  [1.13664782]]
# [[1.13063347]
#  [1.1356796 ]
#  [1.13752699]
#  [1.13664782]
#  [1.13172102]]
# [[1.1356796 ]
#  [1.13752699]
#  [1.13664782]
#  [1.13172102]
#  [1.13096583]]
# [[1.13752699]
#  [1.13664782]
#  [1.13172102]
#  [1.13096583]
#  [1.13291335]]
# [[1.13664782]
#  [1.13172102]
#  [1.13096583]
#  [1.13291335]
#  [1.13056946]]
# [[1.13172102]
#  [1.13096583]
#  [1.13291335]
#  [1.13056946]
#  [1.11906898]]
# [[1.13096583]
#  [1.13291335]
#  [1.13056946]
#  [1.11906898]
#  [1.11810541]]
# [[1.13291335]
#  [1.13056946]
#  [1.11906898]
#  [1.11810541]
#  [1.12159181]]
# [[1.13056946]
#  [1.11906898]
#  [1.11810541]
#  [1.12159181]
#  [1.11327589]]
# [[1.11906898]
#  [1.11810541]
#  [1.12159181]
#  [1.11327589]
#  [1.11123455]]
# [[1.11810541]
#  [1.12159181]
#  [1.11327589]
#  [1.11123455]
#  [1.10668445]]
# [[1.12159181]
#  [1.11327589]
#  [1.11123455]
#  [1.10668445]
#  [1.08745301]]
# [[1.11327589]
#  [1.11123455]
#  [1.10668445]
#  [1.08745301]
#  [1.08653128]]
# [[1.11123455]
#  [1.10668445]
#  [1.08745301]
#  [1.08653128]
#  [1.08982325]]
# [[1.10668445]
#  [1.08745301]
#  [1.08653128]
#  [1.08982325]
#  [1.10738289]]
# [[1.08745301]
#  [1.08653128]
#  [1.08982325]
#  [1.10738289]
#  [1.10139441]]
# [[1.08653128]
#  [1.08982325]
#  [1.10738289]
#  [1.10139441]
#  [1.09320676]]
# [[1.08982325]
#  [1.10738289]
#  [1.10139441]
#  [1.09320676]
#  [1.09431934]]
# [[1.10738289]
#  [1.10139441]
#  [1.09320676]
#  [1.09431934]
#  [1.09693635]]
# [[1.10139441]
#  [1.09320676]
#  [1.09431934]
#  [1.09693635]
#  [1.1021955 ]]
# [[1.09320676]
#  [1.09431934]
#  [1.09693635]
#  [1.1021955 ]
#  [1.10995185]]
# [[1.09431934]
#  [1.09693635]
#  [1.1021955 ]
#  [1.10995185]
#  [1.10431349]]
# [[1.09693635]
#  [1.1021955 ]
#  [1.10995185]
#  [1.10431349]
#  [1.101722  ]]
# [[1.1021955 ]
#  [1.10995185]
#  [1.10431349]
#  [1.101722  ]
#  [1.10297358]]
# [[1.10995185]
#  [1.10431349]
#  [1.101722  ]
#  [1.10297358]
#  [1.10063064]]
# [[1.10431349]
#  [1.101722  ]
#  [1.10297358]
#  [1.10063064]
#  [1.10095787]]
# [[1.101722  ]
#  [1.10297358]
#  [1.10063064]
#  [1.10095787]
#  [1.09818912]]
# [[1.10297358]
#  [1.10063064]
#  [1.10095787]
#  [1.09818912]
#  [1.09938431]]
# [[1.10063064]
#  [1.10095787]
#  [1.09818912]
#  [1.09938431]
#  [1.1091516 ]]
# [[1.10095787]
#  [1.09818912]
#  [1.09938431]
#  [1.1091516 ]
#  [1.11618352]]
# [[1.09818912]
#  [1.09938431]
#  [1.1091516 ]
#  [1.11618352]
#  [1.10723579]]
# [[1.09938431]
#  [1.1091516 ]
#  [1.11618352]
#  [1.10723579]
#  [1.10472822]]
# [[1.1091516 ]
#  [1.11618352]
#  [1.10723579]
#  [1.10472822]
#  [1.09758639]]
# [[1.11618352]
#  [1.10723579]
#  [1.10472822]
#  [1.09758639]
#  [1.09064329]]
# [[1.10723579]
#  [1.10472822]
#  [1.09758639]
#  [1.09064329]
#  [1.08982325]]
# [[1.10472822]
#  [1.09758639]
#  [1.09064329]
#  [1.08982325]
#  [1.08648407]]
# [[1.09758639]
#  [1.09064329]
#  [1.08982325]
#  [1.08648407]
#  [1.08849466]]
# [[1.09064329]
#  [1.08982325]
#  [1.08648407]
#  [1.08849466]
#  [1.08779597]]
# [[1.08982325]
#  [1.08648407]
#  [1.08849466]
#  [1.08779597]
#  [1.0826143 ]]
# [[1.08648407]
#  [1.08849466]
#  [1.08779597]
#  [1.0826143 ]
#  [1.08965695]]
# [[1.08849466]
#  [1.08779597]
#  [1.0826143 ]
#  [1.08965695]
#  [1.08209884]]
# [[1.08779597]
#  [1.0826143 ]
#  [1.08965695]
#  [1.08209884]
#  [1.08152544]]
# [[1.0826143 ]
#  [1.08965695]
#  [1.08209884]
#  [1.08152544]
#  [1.07817876]]
# [[1.08965695]
#  [1.08209884]
#  [1.08152544]
#  [1.07817876]
#  [1.07944727]]
# [[1.08209884]
#  [1.08152544]
#  [1.07817876]
#  [1.07944727]
#  [1.08498704]]
# [[1.08152544]
#  [1.07817876]
#  [1.07944727]
#  [1.08498704]
#  [1.08351755]]
# [[1.07817876]
#  [1.07944727]
#  [1.08498704]
#  [1.08351755]
#  [1.08110452]]
# [[1.07944727]
#  [1.08498704]
#  [1.08351755]
#  [1.08110452]
#  [1.07142091]]
# [[1.08498704]
#  [1.08351755]
#  [1.08110452]
#  [1.07142091]
#  [1.06436193]]
# [[1.08351755]
#  [1.08110452]
#  [1.07142091]
#  [1.06436193]
#  [1.05550921]]
# [[1.08110452]
#  [1.07142091]
#  [1.06436193]
#  [1.05550921]
#  [1.05042017]]
# [[1.07142091]
#  [1.06436193]
#  [1.05550921]
#  [1.05042017]
#  [1.0535965 ]]
# [[1.06436193]
#  [1.05550921]
#  [1.05042017]
#  [1.0535965 ]
#  [1.05090582]]
# [[1.05550921]
#  [1.05042017]
#  [1.0535965 ]
#  [1.05090582]
#  [1.05285323]]
# [[1.05042017]
#  [1.0535965 ]
#  [1.05090582]
#  [1.05285323]
#  [1.06224775]]
# [[1.0535965 ]
#  [1.05090582]
#  [1.05285323]
#  [1.06224775]
#  [1.05397403]]
# [[1.05090582]
#  [1.05285323]
#  [1.06224775]
#  [1.05397403]
#  [1.0532192 ]]
# [[1.05285323]
#  [1.06224775]
#  [1.05397403]
#  [1.0532192 ]
#  [1.05657983]]
# [[1.06224775]
#  [1.05397403]
#  [1.0532192 ]
#  [1.05657983]
#  [1.0532968 ]]
# [[1.05397403]
#  [1.0532192 ]
#  [1.05657983]
#  [1.0532968 ]
#  [1.05124831]]
# [[1.0532192 ]
#  [1.05657983]
#  [1.0532968 ]
#  [1.05124831]
#  [1.03795815]]
# [[1.05657983]
#  [1.0532968 ]
#  [1.05124831]
#  [1.03795815]
#  [1.04006326]]
# [[1.0532968 ]
#  [1.05124831]
#  [1.03795815]
#  [1.04006326]
#  [1.04389584]]
# [[1.05124831]
#  [1.03795815]
#  [1.04006326]
#  [1.04389584]
#  [1.05478561]]
# [[1.03795815]
#  [1.04006326]
#  [1.04389584]
#  [1.05478561]
#  [1.04727399]]
# [[1.04006326]
#  [1.04389584]
#  [1.05478561]
#  [1.04727399]
#  [1.05789876]]
# [[1.04389584]
#  [1.05478561]
#  [1.04727399]
#  [1.05789876]
#  [1.05698192]]
# [[1.05478561]
#  [1.04727399]
#  [1.05789876]
#  [1.05698192]
#  [1.06820488]]
# [[1.04727399]
#  [1.05789876]
#  [1.05698192]
#  [1.06820488]
#  [1.07365251]]
# [[1.05789876]
#  [1.05698192]
#  [1.06820488]
# ...
#  [0.97100574]
#  [0.97001678]
#  [0.97079843]
#  [0.97513402]]
# [[0.97100574]
#  [0.97001678]
#  [0.97079843]
#  [0.97513402]
#  [0.97393745]]
# [[0.97001678]
#  [0.97079843]
#  [0.97513402]
#  [0.97393745]
#  [0.98463964]]
# [[0.97079843]
#  [0.97513402]
#  [0.97393745]
#  [0.98463964]
#  [0.98638785]]
# [[0.97513402]
#  [0.97393745]
#  [0.98463964]
#  [0.98638785]
#  [0.97664827]]
# [[0.97393745]
#  [0.98463964]
#  [0.98638785]
#  [0.97664827]
#  [0.97788996]]
# [[0.98463964]
#  [0.98638785]
#  [0.97664827]
#  [0.97788996]
#  [0.98600858]]
# [[0.98638785]
#  [0.97664827]
#  [0.97788996]
#  [0.98600858]
#  [0.98865032]]
# [[0.97664827]
#  [0.97788996]
#  [0.98600858]
#  [0.98865032]
#  [0.99637312]]
# [[0.97788996]
#  [0.98600858]
#  [0.98865032]
#  [0.99637312]
#  [1.00919378]]
# [[0.98600858]
#  [0.98865032]
#  [0.99637312]
#  [1.00919378]
#  [0.9967804 ]]
# [[0.98865032]
#  [0.99637312]
#  [1.00919378]
#  [0.9967804 ]
#  [0.99550027]]
# [[0.99637312]
#  [1.00919378]
#  [0.9967804 ]
#  [0.99550027]
#  [0.98863077]]
# [[1.00919378]
#  [0.9967804 ]
#  [0.99550027]
#  [0.98863077]
#  [0.98779094]]
# [[0.9967804 ]
#  [0.99550027]
#  [0.98863077]
#  [0.98779094]
#  [0.9814409 ]]
# [[0.99550027]
#  [0.98863077]
#  [0.98779094]
#  [0.9814409 ]
#  [0.97496301]]
# [[0.98863077]
#  [0.98779094]
#  [0.9814409 ]
#  [0.97496301]
#  [0.99288106]]
# [[0.98779094]
#  [0.9814409 ]
#  [0.97496301]
#  [0.99288106]
#  [1.00186348]]
# [[0.9814409 ]
#  [0.97496301]
#  [0.99288106]
#  [1.00186348]
#  [1.00808477]]
# [[0.97496301]
#  [0.99288106]
#  [1.00186348]
#  [1.00808477]
#  [1.00195384]]
# [[0.99288106]
#  [1.00186348]
#  [1.00808477]
#  [1.00195384]
#  [1.0192225 ]]
# [[1.00186348]
#  [1.00808477]
#  [1.00195384]
#  [1.0192225 ]
#  [1.03285515]]
# [[1.00808477]
#  [1.00195384]
#  [1.0192225 ]
#  [1.03285515]
#  [1.03192782]]
# [[1.00195384]
#  [1.0192225 ]
#  [1.03285515]
#  [1.03192782]
#  [1.03578639]]
# [[1.0192225 ]
#  [1.03285515]
#  [1.03192782]
#  [1.03578639]
#  [1.03950107]]
# [[1.03285515]
#  [1.03192782]
#  [1.03578639]
#  [1.03950107]
#  [1.03617287]]
# [[1.03192782]
#  [1.03578639]
#  [1.03950107]
#  [1.03617287]
#  [1.03308988]]
# [[1.03578639]
#  [1.03950107]
#  [1.03617287]
#  [1.03308988]
#  [1.02456915]]
# [[1.03950107]
#  [1.03617287]
#  [1.03308988]
#  [1.02456915]
#  [1.03110862]]
# [[1.03617287]
#  [1.03308988]
#  [1.02456915]
#  [1.03110862]
#  [1.04162335]]
# [[1.03308988]
#  [1.02456915]
#  [1.03110862]
#  [1.04162335]
#  [1.04081023]]
# [[1.02456915]
#  [1.03110862]
#  [1.04162335]
#  [1.04081023]
#  [1.03675282]]
# [[1.03110862]
#  [1.04162335]
#  [1.04081023]
#  [1.03675282]
#  [1.03455412]]
# [[1.04162335]
#  [1.04081023]
#  [1.03675282]
#  [1.03455412]
#  [1.03244996]]
# [[1.04081023]
#  [1.03675282]
#  [1.03455412]
#  [1.03244996]
#  [1.04253542]]
# [[1.03675282]
#  [1.03455412]
#  [1.03244996]
#  [1.04253542]
#  [1.05284214]]
# [[1.03455412]
#  [1.03244996]
#  [1.04253542]
#  [1.05284214]
#  [1.05441856]]
# [[1.03244996]
#  [1.04253542]
#  [1.05284214]
#  [1.05441856]
#  [1.04969239]]
# [[1.04253542]
#  [1.05284214]
#  [1.05441856]
#  [1.04969239]
#  [1.04690111]]
# [[1.05284214]
#  [1.05441856]
#  [1.04969239]
#  [1.04690111]
#  [1.0513258 ]]
# [[1.05441856]
#  [1.04969239]
#  [1.04690111]
#  [1.0513258 ]
#  [1.05596614]]
# [[1.04969239]
#  [1.04690111]
#  [1.0513258 ]
#  [1.05596614]
#  [1.05222178]]
# [[1.04690111]
#  [1.0513258 ]
#  [1.05596614]
#  [1.05222178]
#  [1.05417395]]
# [[1.0513258 ]
#  [1.05596614]
#  [1.05222178]
#  [1.05417395]
#  [1.06266534]]
# [[1.05596614]
#  [1.05222178]
#  [1.05417395]
#  [1.06266534]
#  [1.0676347 ]]
# [[1.05222178]
#  [1.05417395]
#  [1.06266534]
#  [1.0676347 ]
#  [1.06405616]]
# [[1.05417395]
#  [1.06266534]
#  [1.0676347 ]
#  [1.06405616]
#  [1.05850351]]
# [[1.06266534]
#  [1.0676347 ]
#  [1.06405616]
#  [1.05850351]
#  [1.06145847]]
# [[1.0676347 ]
#  [1.06405616]
#  [1.05850351]
#  [1.06145847]
#  [1.06269932]]
# [[1.06405616]
#  [1.05850351]
#  [1.06145847]
#  [1.06269932]
#  [1.06100798]]
# [[1.05850351]
#  [1.06145847]
#  [1.06269932]
#  [1.06100798]
#  [1.06033301]]
# [[1.06145847]
#  [1.06269932]
#  [1.06100798]
#  [1.06033301]
#  [1.06678045]]
# [[1.06269932]
#  [1.06100798]
#  [1.06033301]
#  [1.06678045]
#  [1.06402218]]
# [[1.06100798]
#  [1.06033301]
#  [1.06678045]
#  [1.06402218]
#  [1.06371665]]
# [[1.06033301]
#  [1.06678045]
#  [1.06402218]
#  [1.06371665]
#  [1.0629251 ]]
# [[1.06678045]
#  [1.06402218]
#  [1.06371665]
#  [1.0629251 ]
#  [1.06607533]]
# [[1.06402218]
#  [1.06371665]
#  [1.0629251 ]
#  [1.06607533]
#  [1.0709734 ]]
# [[1.06371665]
#  [1.0629251 ]
#  [1.06607533]
#  [1.0709734 ]
#  [1.06777143]]
# [[1.0629251 ]
#  [1.06607533]
#  [1.0709734 ]
#  [1.06777143]
#  [1.05468547]]
# [[1.06607533]
#  [1.0709734 ]
#  [1.06777143]
#  [1.05468547]
#  [1.06063652]]
# [[1.0709734 ]
#  [1.06777143]
#  [1.05468547]
#  [1.06063652]
#  [1.05222178]]
# [[1.06777143]
#  [1.05468547]
#  [1.06063652]
#  [1.05222178]
#  [1.06563234]]
# [[1.05468547]
#  [1.06063652]
#  [1.05222178]
#  [1.06563234]
#  [1.07331836]]
# [[1.06063652]
#  [1.05222178]
#  [1.06563234]
#  [1.07331836]
#  [1.07389462]]
# [[1.05222178]
#  [1.06563234]
#  [1.07331836]
#  [1.07389462]
#  [1.07660007]]
# [[1.06563234]
#  [1.07331836]
#  [1.07389462]
#  [1.07660007]
#  [1.08602393]]
# [[1.07331836]
#  [1.07389462]
#  [1.07660007]
#  [1.08602393]
#  [1.08246195]]
# [[1.07389462]
#  [1.07660007]
#  [1.08602393]
#  [1.08246195]
#  [1.08301294]]
# [[1.07660007]
#  [1.08602393]
#  [1.08246195]
#  [1.08301294]
#  [1.0793308 ]]
# [[1.08602393]
#  [1.08246195]
#  [1.08301294]
#  [1.0793308 ]
#  [1.07978535]]
# [[1.08246195]
#  [1.08301294]
#  [1.0793308 ]
#  [1.07978535]
#  [1.08338833]]
# [[1.08301294]
#  [1.0793308 ]
#  [1.07978535]
#  [1.08338833]
#  [1.0865078 ]]
# [[1.0793308 ]
#  [1.07978535]
#  [1.08338833]
#  [1.0865078 ]
#  [1.08742929]]
# [[1.07978535]
#  [1.08338833]
#  [1.0865078 ]
#  [1.08742929]
#  [1.08881462]]
# [[1.08338833]
#  [1.0865078 ]
#  [1.08742929]
#  [1.08881462]
#  [1.09220386]]
# [[1.0865078 ]
#  [1.08742929]
#  [1.08881462]
#  [1.09220386]
#  [1.08944321]]
# [[1.08742929]
#  [1.08881462]
#  [1.09220386]
#  [1.08944321]
#  [1.08714557]]
# [[1.08881462]
#  [1.09220386]
#  [1.08944321]
#  [1.08714557]
#  [1.08506942]]
# [[1.09220386]
#  [1.08944321]
#  [1.08714557]
#  [1.08506942]
#  [1.08609474]]
# [[1.08944321]
#  [1.08714557]
#  [1.08506942]
#  [1.08609474]
#  [1.10128522]]
# [[1.08714557]
#  [1.08506942]
#  [1.08609474]
#  [1.10128522]
#  [1.09051251]]
# [[1.08506942]
#  [1.08609474]
#  [1.10128522]
#  [1.09051251]
#  [1.07908618]]
# [[1.08609474]
#  [1.10128522]
#  [1.09051251]
#  [1.07908618]
#  [1.07307649]]
# [[1.10128522]
#  [1.09051251]
#  [1.07908618]
#  [1.07307649]
#  [1.07297289]]
# [[1.09051251]
#  [1.07908618]
#  [1.07307649]
#  [1.07297289]
#  [1.0715816 ]]
# [[1.07908618]
#  [1.07307649]
#  [1.07297289]
#  [1.0715816 ]
#  [1.07422924]]
# [[1.07307649]
#  [1.07297289]
#  [1.0715816 ]
#  [1.07422924]
#  [1.06777143]]
# [[1.07297289]
#  [1.0715816 ]
#  [1.07422924]
#  [1.06777143]
#  [1.07304192]]
# [[1.0715816 ]
#  [1.07422924]
#  [1.06777143]
#  [1.07304192]
#  [1.07357192]]
# [[1.07422924]
#  [1.06777143]
#  [1.07304192]
#  [1.07357192]
#  [1.06917572]]
# [[1.06777143]
#  [1.07304192]
#  [1.07357192]
#  [1.06917572]
#  [1.06657565]]
# [[1.07304192]
#  [1.07357192]
#  [1.06917572]
#  [1.06657565]
#  [1.06844449]]
# [[1.07357192]
#  [1.06917572]
#  [1.06657565]
#  [1.06844449]
#  [1.06826198]]
# [[1.06917572]
#  [1.06657565]
#  [1.06844449]
#  [1.06826198]
#  [1.06520092]]
# [[1.06657565]
#  [1.06844449]
#  [1.06826198]
#  [1.06520092]
#  [1.06058037]]
# [[1.06844449]
#  [1.06826198]
#  [1.06520092]
#  [1.06058037]
#  [1.0598048 ]]
# [[1.06826198]
#  [1.06520092]
#  [1.06058037]
#  [1.0598048 ]
#  [1.05547583]]
# [[1.06520092]
#  [1.06058037]
#  [1.0598048 ]
#  [1.05547583]
#  [1.06112051]]
# [[1.06058037]
#  [1.0598048 ]
#  [1.05547583]
#  [1.06112051]
#  [1.05773091]]
# [[1.0598048 ]
#  [1.05547583]
#  [1.06112051]
#  [1.05773091]
#  [1.06689429]]
# [[1.05547583]
#  [1.06112051]
#  [1.05773091]
#  [1.06689429]
#  [1.05997324]]
# [[1.06112051]
#  [1.05773091]
#  [1.06689429]
#  [1.05997324]
#  [1.06262016]]
# [[1.05773091]
#  [1.06689429]
#  [1.05997324]
#  [1.06262016]
#  [1.06883287]]
# [[1.06689429]
#  [1.05997324]
#  [1.06262016]
#  [1.06883287]
#  [1.05507493]]
# [[1.05997324]
#  [1.06262016]
#  [1.06883287]
#  [1.05507493]
#  [1.0549525 ]]
# [[1.06262016]
#  [1.06883287]
#  [1.05507493]
#  [1.0549525 ]
#  [1.05846989]]
# [[1.06883287]
#  [1.05507493]
#  [1.0549525 ]
#  [1.05846989]
#  [1.06836462]]
# [[1.05507493]
#  [1.0549525 ]
#  [1.05846989]
#  [1.06836462]
#  [1.07250106]]
# [[1.0549525 ]
#  [1.05846989]
#  [1.06836462]
#  [1.07250106]
#  [1.07276571]]
# [[1.05846989]
#  [1.06836462]
#  [1.07250106]
#  [1.07276571]
#  [1.05833542]]
# [[1.06836462]
#  [1.07250106]
#  [1.07276571]
#  [1.05833542]
#  [1.06141341]]
# [[1.07250106]
#  [1.07276571]
#  [1.05833542]
#  [1.06141341]
#  [1.06788552]]
# [[1.07276571]
#  [1.05833542]
#  [1.06141341]
#  [1.06788552]
#  [1.07191479]]
# [[1.05833542]
#  [1.06141341]
#  [1.06788552]
#  [1.07191479]
#  [1.07742369]]
# [[1.06141341]
#  [1.06788552]
#  [1.07191479]
#  [1.07742369]
#  [1.08703923]]
# [[1.06788552]
#  [1.07191479]
#  [1.07742369]
#  [1.08703923]
#  [1.08350575]]
# [[1.07191479]
#  [1.07742369]
#  [1.08703923]
#  [1.08350575]
#  [1.07781851]]
# [[1.07742369]
#  [1.08703923]
#  [1.08350575]
#  [1.07781851]
#  [1.08070719]]
# [[1.08703923]
#  [1.08350575]
#  [1.07781851]
#  [1.08070719]
#  [1.08395207]]
# [[1.08350575]
#  [1.07781851]
#  [1.08070719]
#  [1.08395207]
#  [1.08436346]]
# [[1.07781851]
#  [1.08070719]
#  [1.08395207]
#  [1.08436346]
#  [1.09046495]]
# [[1.08070719]
#  [1.08395207]
#  [1.08436346]
#  [1.09046495]
#  [1.08033359]]
# [[1.08395207]
#  [1.08436346]
#  [1.09046495]
#  [1.08033359]
#  [1.09122658]]
# [[1.08436346]
#  [1.09046495]
#  [1.08033359]
#  [1.09122658]
#  [1.09601057]]
# [[1.09046495]
#  [1.08033359]
#  [1.09122658]
#  [1.09601057]
#  [1.09033418]]
# [[1.08033359]
#  [1.09122658]
#  [1.09601057]
#  [1.09033418]
#  [1.092013  ]]
# [[1.09122658]
#  [1.09601057]
#  [1.09033418]
#  [1.092013  ]
#  [1.09135759]]
# [[1.09601057]
#  [1.09033418]
#  [1.092013  ]
#  [1.09135759]
#  [1.0869329 ]]
# [[1.09033418]
#  [1.092013  ]
#  [1.09135759]
#  [1.0869329 ]
#  [1.09175074]]
# [[1.092013  ]
#  [1.09135759]
#  [1.0869329 ]
#  [1.09175074]
#  [1.09998906]]
# [[1.09135759]
#  [1.0869329 ]
#  [1.09175074]
#  [1.09998906]
#  [1.105461  ]]
# [[1.0869329 ]
#  [1.09175074]
#  [1.09998906]
#  [1.105461  ]
#  [1.09865963]]
# [[1.09175074]
#  [1.09998906]
#  [1.105461  ]
#  [1.09865963]
#  [1.092538  ]]
# [[1.09998906]
#  [1.105461  ]
#  [1.09865963]
#  [1.092538  ]
#  [1.09753823]]
# [[1.105461  ]
#  [1.09865963]
#  [1.092538  ]
#  [1.09753823]
#  [1.0952183 ]]
# [[1.09865963]
#  [1.092538  ]
#  [1.09753823]
#  [1.0952183 ]
#  [1.09709275]]
# [[1.092538  ]
#  [1.09753823]
#  [1.0952183 ]
#  [1.09709275]
#  [1.09922719]]
# [[1.09753823]
#  [1.0952183 ]
#  [1.09709275]
#  [1.09922719]
#  [1.10595   ]]
# [[1.0952183 ]
#  [1.09709275]
#  [1.09922719]
#  [1.10595   ]
#  [1.09783947]]
# [[1.09709275]
#  [1.09922719]
#  [1.10595   ]
#  [1.09783947]
#  [1.10472822]]
# [[1.09922719]
#  [1.10595   ]
#  [1.09783947]
#  [1.10472822]
#  [1.10320485]]
# [[1.10595   ]
#  [1.09783947]
#  [1.10472822]
#  [1.10320485]
#  [1.10109115]]
# [[1.09783947]
#  [1.10472822]
#  [1.10320485]
#  [1.10109115]
#  [1.09692419]]
# [[1.10472822]
#  [1.10320485]
#  [1.10109115]
#  [1.09692419]
#  [1.10109115]]
# [[1.10320485]
#  [1.10109115]
#  [1.09692419]
#  [1.10109115]
#  [1.10689259]]
# [[1.10109115]
#  [1.09692419]
#  [1.10109115]
#  [1.10689259]
#  [1.10229278]]
# [[1.09692419]
#  [1.10109115]
#  [1.10689259]
#  [1.10229278]
#  [1.10186768]]
# [[1.10109115]
#  [1.10689259]
#  [1.10229278]
#  [1.10186768]
#  [1.09961402]]
# [[1.10689259]
#  [1.10229278]
#  [1.10186768]
#  [1.09961402]
#  [1.09646714]]
# [[1.10229278]
#  [1.10186768]
#  [1.09961402]
#  [1.09646714]
#  [1.0984062 ]]
# [[1.10186768]
#  [1.09961402]
#  [1.09646714]
#  [1.0984062 ]
#  [1.09121454]]
# [[1.09961402]
#  [1.09646714]
#  [1.0984062 ]
#  [1.09121454]
#  [1.08526969]]
# [[1.09646714]
#  [1.0984062 ]
#  [1.09121454]
#  [1.08526969]
#  [1.08737016]]
# [[1.0984062 ]
#  [1.09121454]
#  [1.08526969]
#  [1.08737016]
#  [1.08656681]]
# [[1.09121454]
#  [1.08526969]
#  [1.08737016]
#  [1.08656681]
#  [1.08383465]]
# [[1.08526969]
#  [1.08737016]
#  [1.08656681]
#  [1.08383465]
#  [1.07753968]]
# [[1.08737016]
#  [1.08656681]
#  [1.08383465]
#  [1.07753968]
#  [1.08227456]]
# [[1.08656681]
#  [1.08383465]
#  [1.07753968]
#  [1.08227456]
#  [1.08110452]]
# [[1.08383465]
#  [1.07753968]
#  [1.08227456]
#  [1.08110452]
#  [1.07697117]]
# [[1.07753968]
#  [1.08227456]
#  [1.08110452]
#  [1.07697117]
#  [1.07573152]]
# [[1.08227456]
#  [1.08110452]
#  [1.07697117]
#  [1.07573152]
#  [1.0724436 ]]
# [[1.08110452]
#  [1.07697117]
#  [1.07573152]
#  [1.0724436 ]
#  [1.07230556]]
# [[1.07697117]
#  [1.07573152]
#  [1.0724436 ]
#  [1.07230556]
#  [1.07076693]]
# [[1.07573152]
#  [1.0724436 ]
#  [1.07230556]
#  [1.07076693]
#  [1.07330692]]
# [[1.0724436 ]
#  [1.07230556]
#  [1.07076693]
#  [1.07330692]
#  [1.06951869]]
# [[1.07230556]
#  [1.07076693]
#  [1.07330692]
#  [1.06951869]
#  [1.07607877]]
# [[1.07076693]
#  [1.07330692]
#  [1.06951869]
#  [1.07607877]
#  [1.06986201]]
# [[1.07330692]
#  [1.06951869]
#  [1.07607877]
#  [1.06986201]
#  [1.07117987]]
# [[1.06951869]
#  [1.07607877]
#  [1.06986201]
#  [1.07117987]
#  [1.06980479]]
# [[1.07607877]
#  [1.06986201]
#  [1.07117987]
#  [1.06980479]
#  [1.07074404]]
# [[1.06986201]
#  [1.07117987]
#  [1.06980479]
#  [1.07074404]
#  [1.07827175]]
# [[1.07117987]
#  [1.06980479]
#  [1.07074404]
#  [1.07827175]
#  [1.07509542]]
# [[1.06980479]
#  [1.07074404]
#  [1.07827175]
#  [1.07509542]
#  [1.07629883]]
# [[1.07074404]
#  [1.07827175]
#  [1.07509542]
#  [1.07629883]
#  [1.07893491]]
# [[1.07827175]
#  [1.07509542]
#  [1.07629883]
#  [1.07893491]
#  [1.08430469]]
# [[1.07509542]
#  [1.07629883]
#  [1.07893491]
#  [1.08430469]
#  [1.09459484]]
# [[1.07629883]
#  [1.07893491]
#  [1.08430469]
#  [1.09459484]
#  [1.09421158]]
# [[1.07893491]
#  [1.08430469]
#  [1.09459484]
#  [1.09421158]
#  [1.09243047]]
# [[1.08430469]
#  [1.09459484]
#  [1.09421158]
#  [1.09243047]
#  [1.09203684]]
# [[1.09459484]
#  [1.09421158]
#  [1.09243047]
#  [1.09203684]
#  [1.09926355]]
# [[1.09421158]
#  [1.09243047]
#  [1.09203684]
#  [1.09926355]
#  [1.0958904 ]]
# [[1.09243047]
#  [1.09203684]
#  [1.09926355]
#  [1.0958904 ]
#  [1.09066713]]
# [[1.09203684]
#  [1.09926355]
#  [1.0958904 ]
#  [1.09066713]
#  [1.091048  ]]
# [[1.09926355]
#  [1.0958904 ]
#  [1.09066713]
#  [1.091048  ]
#  [1.09572232]]
# [[1.0958904 ]
#  [1.09066713]
#  [1.091048  ]
#  [1.09572232]
#  [1.09158385]]
# [[1.09066713]
#  [1.091048  ]
#  [1.09572232]
#  [1.09158385]
#  [1.08680296]]
# [[1.091048  ]
#  [1.09572232]
#  [1.09158385]
#  [1.08680296]
#  [1.09075046]]
# [[1.09572232]
#  [1.09158385]
#  [1.08680296]
#  [1.09075046]
#  [1.09130991]]
# [[1.09158385]
#  [1.08680296]
#  [1.09075046]
#  [1.09130991]
#  [1.08849466]]
# [[1.08680296]
#  [1.09075046]
#  [1.09130991]
#  [1.08849466]
#  [1.08565843]]
# [[1.09075046]
#  [1.09130991]
#  [1.08849466]
#  [1.08565843]
#  [1.08906364]]
# [[1.09130991]
#  [1.08849466]
#  [1.08565843]
#  [1.08906364]
#  [1.09697235]]
# [[1.08849466]
#  [1.08565843]
#  [1.08906364]
#  [1.09697235]
#  [1.1005944 ]]
# [[1.08565843]
#  [1.08906364]
#  [1.09697235]
#  [1.1005944 ]
#  [1.10140646]]
# [[1.08906364]
#  [1.09697235]
#  [1.1005944 ]
#  [1.10140646]
#  [1.11445451]]
# [[1.09697235]
#  [1.1005944 ]
#  [1.10140646]
#  [1.11445451]
#  [1.122347  ]]
# [[1.1005944 ]
#  [1.10140646]
#  [1.11445451]
#  [1.122347  ]
#  [1.12277555]]
# [[1.10140646]
#  [1.11445451]
#  [1.122347  ]
#  [1.12277555]
#  [1.12375963]]
# [[1.11445451]
#  [1.122347  ]
#  [1.12277555]
#  [1.12375963]
#  [1.12288904]]
# [[1.122347  ]
#  [1.12277555]
#  [1.12375963]
#  [1.12288904]
#  [1.12052345]]
# [[1.12277555]
#  [1.12375963]
#  [1.12288904]
#  [1.12052345]
#  [1.11370981]]
# [[1.12375963]
#  [1.12288904]
#  [1.12052345]
#  [1.11370981]
#  [1.11253262]]
# [[1.12288904]
#  [1.12052345]
#  [1.11370981]
#  [1.11253262]
#  [1.10631704]]
# [[1.12052345]
#  [1.11370981]
#  [1.11253262]
#  [1.10631704]
#  [1.10504568]]
# [[1.11370981]
#  [1.11253262]
#  [1.10631704]
#  [1.10504568]
#  [1.10783684]]
# [[1.11253262]
#  [1.10631704]
#  [1.10504568]
#  [1.10783684]
#  [1.0978756 ]]
# [[1.10631704]
#  [1.10504568]
#  [1.10783684]
#  [1.0978756 ]
#  [1.10242641]]
# [[1.10504568]
#  [1.10783684]
#  [1.0978756 ]
#  [1.10242641]
#  [1.0997591 ]]
# [[1.10783684]
#  [1.0978756 ]
#  [1.10242641]
#  [1.0997591 ]
#  [1.10078812]]
# [[1.0978756 ]
#  [1.10242641]
#  [1.0997591 ]
#  [1.10078812]
#  [1.09441519]]
# [[1.10242641]
#  [1.0997591 ]
#  [1.10078812]
#  [1.09441519]
#  [1.09515834]]
# [[1.0997591 ]
#  [1.10078812]
#  [1.09441519]
#  [1.09515834]
#  [1.10026741]]
# [[1.10078812]
#  [1.09441519]
#  [1.09515834]
#  [1.10026741]
#  [1.10031581]]
# [[1.09441519]
#  [1.09515834]
#  [1.10026741]
#  [1.10031581]
#  [1.0958904 ]]
# [[1.09515834]
#  [1.10026741]
#  [1.10031581]
#  [1.0958904 ]
#  [1.09776711]]
# [[1.10026741]
#  [1.10031581]
#  [1.0958904 ]
#  [1.09776711]
#  [1.09816492]]
# [[1.10031581]
#  [1.0958904 ]
#  [1.09776711]
#  [1.09816492]
#  [1.09443915]]
# [[1.0958904 ]
#  [1.09776711]
#  [1.09816492]
#  [1.09443915]
#  [1.0909884 ]]
# [[1.09776711]
#  [1.09816492]
#  [1.09443915]
#  [1.0909884 ]
#  [1.09041739]]
# [[1.09816492]
#  [1.09443915]
#  [1.0909884 ]
#  [1.09041739]
#  [1.08748841]]
# [[1.09443915]
#  [1.0909884 ]
#  [1.09041739]
#  [1.08748841]
#  [1.08746481]]
# [[1.0909884 ]
#  [1.09041739]
#  [1.08748841]
#  [1.08746481]
#  [1.08755946]]
# [[1.09041739]
#  [1.08748841]
#  [1.08746481]
#  [1.08755946]
#  [1.08983517]]
# [[1.08748841]
#  [1.08746481]
#  [1.08755946]
#  [1.08983517]
#  [1.08466923]]
# Transformer Mean Absolute Error: 0.0077589595763702095
# Transformet Mean Squared Error: 0.010249992093387176

# %% [markdown]
# ## Visualizations

# %%
def plot_results(test, preds, df, image_path=None, title_suffix=None, xlabel='EURUSD price'):
  """
  Plots training data in blue, actual values in red, and predictions in green,
  over time.
  """
  fig, ax = plt.subplots(figsize=(20,6))

  plot_test = test[1:]
  plot_preds = preds[1:]
  x = df[-(plot_test.shape[0]*plot_test.shape[1]):].index
  plot_test = plot_test.reshape((plot_test.shape[0]*plot_test.shape[1], 1))
  plot_preds = plot_preds.reshape((plot_test.shape[0]*plot_test.shape[1], 1))
  ax.plot(x, plot_test, label='actual')
  ax.plot(x, plot_preds, label='preds')

  if title_suffix==None:
    ax.set_title('Predictions vs. Actual')
  else:
    ax.set_title(f'Predictions vs. Actual, {title_suffix}')

  ax.set_xlabel('Date')
  ax.set_ylabel(xlabel)
  ax.legend()
  if image_path != None:
    imagedir = './result_plots'
    plt.savefig(f'{imagedir}/{image_path}.png')
  plt.show()

# %% [markdown]
# ### Transformer

# %%
plot_results(etl_data.X_test, transformer_predictions, etl_data.df, title_suffix='Transformer')

# %% [markdown]
# Save and serialize models for the bot

# %%
# save models for bot usage
nbeats_model.save('./model_dumps/nbeats.keras')
nhits_model.save('./model_dumps/nhits.keras')
rnn_model.save('./model_dumps/rnn.keras')
lstm_model.save('./model_dumps/lstm.keras')
transformer_model.save('./model_dumps/transformer.keras')
